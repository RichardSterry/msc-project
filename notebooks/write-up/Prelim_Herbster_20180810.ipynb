# %% [markdown]
# # Copy of old notebook so I can steal bits for project write-up
# * Copied from aws-big\Presentation_MarkHerbster_20180608
# * Running in msc-project-master
# * on aws-spot
# * This was originally used as a Jupyter presentation for my first meeting with Mark
# * Going to check I can recreate it and save a few bits for the write-up

# %%
save_folder = '/home/ubuntu/msc-project-master/msc-project-master/docs/master'

# %%
import os
import pandas as pd
from IPython.display import Audio
from IPython.display import Image
from IPython.display import SVG
from IPython.display import SVG, display
from IPython.core.display import HTML 
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.core.display import Image, display
import matplotlib.cm as cm

from torch.autograd import Variable
from IPython.display import Audio
import IPython.display

import phonemizer
import torch

from data import *
from model import Loop
from utils import generate_merlin_wav

# %%
# %matplotlib inline
import IPython.display
from ipywidgets import interact, interactive, fixed

import numpy as np
import matplotlib.pyplot as plt
import copy
from scipy.io import wavfile
#from scipy.signal import butter, lfilter
#import scipy.ndimage
import os
import argparse

#import spectrograms.spectrogram_utils as su

#import winsound
import pandas as pd

import glob as gl
from IPython.display import display, HTML

import pydub as pyd
import spectrogram as sp
from utils import generate_merlin_wav

from shutil import copyfile

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
os.chdir('/home/ubuntu/loop')
vctk_folder = '/home/ubuntu/VCTK-Corpus/'

# %%
def get_vtck_speaker_info():
    # this is the reference data file that comes as part of VCTK
    speaker_info_file = os.path.join(vctk_folder, 'speaker-info.txt')

   # read file contents
    f = open(speaker_info_file, 'r')
    x = f.readlines()
    f.close()

    # extract column headers
    cols = x[0].lower().split()
    num_cols = len(cols)
    del x[0]
    num_speaker = len(x)

    # parse the data line by line
    d = dict()

    for idx in range(num_speaker):
        this_speaker_id = int(x[idx][:3])
        this_age = int(x[idx][5:7])
        this_gender = x[idx][9]
        residual = x[idx][14:].split()
        this_accent = residual[0]
        this_region = " ".join(residual[1:])

        # add speakers to a dictionary
        d[this_speaker_id] = (this_speaker_id, this_age, this_gender, this_accent, this_region)

    # convert to Pandas datafrae
    speaker_info = pd.DataFrame.from_dict(d, orient='index', columns=cols)
    
    return speaker_info

# %%
from IPython.display import SVG
def show_svg():
    return SVG(url='http://upload.wikimedia.org/wikipedia/en/a/a4/Flag_of_the_United_States.svg')

# %%
def plot_spectrogram(wav_data, rate, title="Original Spectrogram"):
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    data = sp.butter_bandpass_filter(wav_data, lowcut, highcut, rate, order=1)
    #data = butter_bandpass_filter(data, 500, 7500, rate, order=1)
    # Only use a short clip for our demo
    if np.shape(data)[0]/float(rate) > 10:
        data = data[0:rate*10] 
    #print('Length in time (s):' + str(np.shape(data)[0]/float(rate)))

    wav_spectrogram = sp.pretty_spectrogram(wav_data.astype('float64'), fft_size = fft_size, 
                                       step_size = step_size, log = True, thresh = spec_thresh)

    fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,4))
    cax = ax.matshow(np.transpose(wav_spectrogram), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    fig.colorbar(cax)
    plt.title(title)
    #plt.xlim(0, len(wav_data))
    #plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))

def load_pre_calc_features(speaker_id, sample_id):
    pre_calc_features_folder = '/home/ubuntu/loop/data/vctk/numpy_features/'
    pre_calc_features_file = os.path.join(pre_calc_features_folder, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
    feats = np.load(pre_calc_features_file)
    
    return feats

def play_synthesized_features(feats, output_file='test.wav'):
    output_dir = './'
    #output_file = 'test.wav'
    norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
    generate_merlin_wav(feats['audio_features'],
                        output_dir,
                        output_file,
                        norm_path)

    IPython.display.display(IPython.display.Audio(output_file + '.wav', autoplay=True))
    
    rate, wav_data = wavfile.read(output_file + '.wav')  
    
    return rate, wav_data

# %%
def play_vctk_sample(vctk_speaker_id, sample_id, fname=None):
    # raw .wav file
    wav_file = os.path.join(vctk_folder, 'wav48/p' + str(vctk_speaker_id) + '/p' + str(vctk_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.wav')

    # print speaker info
    display(speaker_info[speaker_info['id']==vctk_speaker_id])

    # print text
    txt_file = wav_file.replace("wav48", "txt").replace(".wav", ".txt")
    f = open(txt_file, 'r')
    print(f.read())
    f.close()
    
    x = feats['phonemes']
    #x[x==42] = 0 # for some reason, sometimes there is a phoneme with index=42, which doesn't appear in the dict.
    print " ".join(feats['code2phone'][x])
    
    if fname:
        copyfile(wav_file, fname)

    # play sample
    rate, wav_data = wavfile.read(wav_file)    
    display(IPython.display.Audio(data=wav_data, rate=rate, autoplay=True))

# %%
def plot_lf0_etc(feats, fname=None):
    # plot lf0, vuv and bap features
    plt.figure(figsize=(20, 4))

    plt.subplot(1, 3, 1)
    plt.plot(feats['audio_features'][:, 60])
    plt.title('vuv')
    plt.grid(True)
    plt.ylabel('Normalised Feature')
    plt.xlabel('Frame')

    plt.subplot(1, 3, 2)
    plt.plot(feats['audio_features'][:, 61])
    plt.title('lf0')
    plt.grid(True)
    plt.ylabel('Normalised Feature')
    plt.xlabel('Frame')

    plt.subplot(1, 3, 3)
    plt.plot(feats['audio_features'][:, 62])
    plt.title('bap')
    plt.grid(True)
    plt.ylabel('Normalised Feature')
    plt.xlabel('Frame')
    
    if fname:
        plt.savefig(fname)

# %%
def display_vctk_sample(vctk_speaker_id, sample_id, fname=None):
    # raw .wav file
    wav_file = os.path.join(vctk_folder, 'wav48/p' + str(vctk_speaker_id) + '/p' + str(vctk_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.wav')

    # print speaker info
    display(speaker_info[speaker_info['id']==vctk_speaker_id])

    # print text
    txt_file = wav_file.replace("wav48", "txt").replace(".wav", ".txt")
    f = open(txt_file, 'r')
    print(f.read())
    f.close()

    # play sample
    rate, wav_data = wavfile.read(wav_file)    
    display(IPython.display.Audio(data=wav_data, rate=rate, autoplay=True))
    
    if fname: 
        copyfile(wav_file, os.path.join(save_folder, os.path.basename(wav_file)))

    # plot waveform
    plt.figure(figsize=(15,4))
    plt.plot(wav_data)
    plt.grid(True)
    plt.xlim(0, len(wav_data))
    plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    if fname:
        plt.savefig(fname)
        
    # plot spectrogram
    plot_spectrogram(wav_data, rate)
    plt.savefig(fname + '_spectro')
    
        

def plot_spectrogram(wav_data, rate, title="Original Spectrogram"):
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    data = sp.butter_bandpass_filter(wav_data, lowcut, highcut, rate, order=1)
    #data = butter_bandpass_filter(data, 500, 7500, rate, order=1)
    # Only use a short clip for our demo
    if np.shape(data)[0]/float(rate) > 10:
        data = data[0:rate*10] 
    #print('Length in time (s):' + str(np.shape(data)[0]/float(rate)))

    wav_spectrogram = sp.pretty_spectrogram(wav_data.astype('float64'), fft_size = fft_size, 
                                       step_size = step_size, log = True, thresh = spec_thresh)

    fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,4))
    cax = ax.matshow(np.transpose(wav_spectrogram), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    fig.colorbar(cax)
    plt.title(title)
    #plt.xlim(0, len(wav_data))
    #plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))

# %%
 def plot_spectrogram_comparison(wav_file_a, wav_file_b, label_a='base', label_b='test',
                                 title="Original Spectrogram", b_mel=False):
        
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    #loop_dict['output_orig_fname']
    #loop_dict['output_fname']
    
    # load wav file data
    mywav_a = wav_file_a + '.wav'
    mywav_b = wav_file_b + '.wav'
    
    rate_a, data_a = wavfile.read(mywav_a)
    data_a = sp.butter_bandpass_filter(data_a, lowcut, highcut, rate_a, order=1)
    
    rate_b, data_b = wavfile.read(mywav_b)
    data_b = sp.butter_bandpass_filter(data_b, lowcut, highcut, rate_b, order=1)
    
    assert rate_a==rate_b, "Sampling rates don't match"
    
    # pad
    max_len = np.max([len(data_a), len(data_b)])
    
    tmp_a = data_a
    data_a = np.zeros(max_len)
    data_a[:len(tmp_a)] = tmp_a
    
    tmp_b = data_b
    data_b = np.zeros(max_len)
    data_b[:len(tmp_b)] = tmp_b
   

    # create spectrograms
    wav_spectrogram_a = sp.pretty_spectrogram(data_a.astype('float64'), fft_size = fft_size, 
                                           step_size = step_size, log = True, thresh = spec_thresh)

    wav_spectrogram_b = sp.pretty_spectrogram(data_b.astype('float64'), fft_size = fft_size, 
                                           step_size = step_size, log = True, thresh = spec_thresh)
    
    # create mel spectrograms if necessary
    if b_mel:        
         # Generate the mel filters
        mel_filter, mel_inversion_filter = sp.create_mel_filter(fft_size = fft_size,
                                                            n_freq_components = n_mel_freq_components,
                                                            start_freq = start_freq,
                                                            end_freq = end_freq, samplerate=rate_a) # may need to change sample rate
    
        # create mel spectrograms
        mel_spec_a = sp.make_mel(wav_spectrogram_a, mel_filter, shorten_factor = shorten_factor)
        mel_spec_b = sp.make_mel(wav_spectrogram_b, mel_filter, shorten_factor = shorten_factor)
        
        # use mel spectrograms in the plots (hacky, needs tidying up)
        wav_spectrogram_a = np.float64(mel_spec_a)
        wav_spectrogram_b = np.float64(mel_spec_b)

   
    # plot spectrograms and the differences
    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_a), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Spectrogram: ' + wav_file_a + '(' + label_a + ')')

    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_b), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Spectrogram: ' + wav_file_b + '(' + label_b + ')')

    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_b - wav_spectrogram_a), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Difference: (' + wav_file_b + ' - ' + wav_file_a + ') (' + label_b + ' - ' + label_a + ')')

# %%
def load_pre_calc_features(speaker_id, sample_id):
    pre_calc_features_folder = '/home/ubuntu/loop/data/vctk/numpy_features/'
    pre_calc_features_file = os.path.join(pre_calc_features_folder, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
    feats = np.load(pre_calc_features_file)
    
    return feats

def play_synthesized_features(feats):
    output_dir = './'
    output_file = 'test.wav'
    norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
    generate_merlin_wav(feats['audio_features'],
                        output_dir,
                        output_file,
                        norm_path)

    IPython.display.display(IPython.display.Audio(output_file + '.wav', autoplay=True))
    
    rate, wav_data = wavfile.read(output_file + '.wav')  
    
    return rate, wav_data

# %%
def generate_sample_with_loop(npz='', text='', spkr_id=1, checkpoint='models/vctk/bestmodel.pth', output_dir = './',
                             npz_path = '/home/ubuntu/loop/data/vctk/numpy_features'):
    #npz = ''
    #text = 'Your tickets for the social issues'
    #text = 'see that girl watch that scene'
    #npz = '/home/ubuntu/loop/data/vctk/numpy_features/p294_011.npz'
    #spkr_id = 12
    #checkpoint = 'checkpoints/vctk/lastmodel.pth'
    #checkpoint = 'models/vctk/bestmodel.pth'
    
    out_dict = dict()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    gpu = 0

    # load loop weights & params from checkpoint
    weights = torch.load(checkpoint,
                         map_location=lambda storage, loc: storage)
    opt = torch.load(os.path.dirname(checkpoint) + '/args.pth')
    train_args = opt[0]

    train_dataset = NpzFolder('/home/ubuntu/loop/data/vctk/numpy_features')
    char2code = train_dataset.dict
    spkr2code = train_dataset.speakers

    norm_path = train_args.data + '/norm_info/norm.dat'
    norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
    train_args.noise = 0
    
    valid_dataset_path = npz_path + '_valid'

    
    # prepare loop model
    model = Loop(train_args)
    model.load_state_dict(weights)
    if gpu >= 0:
        model.cuda()
    model.eval()

    # check speaker id is valid
    if spkr_id not in range(len(spkr2code)):
        print('ERROR: Unknown speaker id: %d.' % spkr_id)

    # get phone sequence
    txt, feat, spkr, output_fname = None, None, None, None
    if npz is not '':
        # use pre-calculated phonemes etc.
        txt, feat, pre_calc_feat = npy_loader_phonemes(os.path.join(npz_path, npz))

        txt = Variable(txt.unsqueeze(1), volatile=True)
        feat = Variable(feat.unsqueeze(1), volatile=True)
        spkr = Variable(torch.LongTensor([spkr_id]), volatile=True)

        output_file = os.path.basename(npz)[:-4] + '_' + str(spkr_id)
        
        out_dict['pre_calc_feat'] = pre_calc_feat
        
    elif text is not '':
        # use specified text string
        # extract phonemes from the text
        txt = text2phone(text, char2code)
        feat = torch.FloatTensor(txt.size(0)*20, 63)
        spkr = torch.LongTensor([spkr_id])

        txt = Variable(txt.unsqueeze(1), volatile=True)
        feat = Variable(feat.unsqueeze(1), volatile=True)
        spkr = Variable(spkr, volatile=True)

        output_file = text.replace(' ', '_')
    else:
        print('ERROR: Must supply npz file path or text as source.')
        raise Exception('Need source')

    # use gpu
    if gpu >= 0:
        txt = txt.cuda()
        feat = feat.cuda()
        spkr = spkr.cuda()

    # run loop model to generate output features 
    loop_feat, attn = model([txt, spkr], feat)
    loop_feat, attn = trim_pred(loop_feat, attn)
    
    # add to output dictionary
    out_dict['txt'] = txt[:,0].squeeze().data.tolist()
    out_dict['spkr'] = spkr
    out_dict['feat'] = feat.data.cpu().numpy()
    out_dict['loop_feat'] = loop_feat.data.cpu().numpy()
    out_dict['attn'] = attn.squeeze().data.cpu().numpy()
    out_dict['output_file'] = output_file
    out_dict['valid_dataset_path'] = valid_dataset_path
    


    # generate .wav file from loop output features
    generate_merlin_wav(loop_feat.data.cpu().numpy(),
                        output_dir,
                        output_file,
                        norm_path)
    
    
    # generate .wav file from original features for reference
    if npz is not '':
        output_orig_fname = os.path.basename(npz)[:-4] + '.orig'
        generate_merlin_wav(feat[:, 0, :].data.cpu().numpy(),
                            output_dir,
                            output_orig_fname,
                            norm_path)
        out_dict['output_orig_fname'] = output_orig_fname
    
    return out_dict

# %%
def plot_attn(data, labels, dict_file):
    labels_dict = dict_file
    labels_dict = {v: k for k, v in labels_dict.iteritems()}
    labels = [labels_dict[x].decode('latin-1') for x in labels]

    plt.figure(figsize=(10,10))
    axarr = plt.subplot()
    axarr.imshow(data.T, aspect='auto', origin='lower', interpolation='nearest', cmap=cm.viridis)
    axarr.set_yticks(np.arange(0, len(data.T)))
    axarr.set_yticklabels(labels, rotation=90)

# %%
def text2phone(text, char2code):
    seperator = phonemizer.separator.Separator('', '', ' ')
    ph = phonemizer.phonemize(text, separator=seperator)
    ph = ph.split(' ')
    ph.remove('')

    ph = [p.replace('zh', 'jh') for p in ph]

    result = [char2code[p] for p in ph]
    return torch.LongTensor(result)

def trim_pred(out, attn):
    tq = attn.abs().sum(1).data

    for stopi in range(1, tq.size(0)):
        col_sum = attn[:stopi, :].abs().sum(0).data.squeeze()

        if type(tq[stopi]) == float:
            if tq[stopi] < 0.5 and col_sum[-1] > 4:
                break
        else:  
            if tq[stopi][0] < 0.5 and col_sum[-1] > 4:
                break

    out = out[:stopi, :]
    attn = attn[:stopi, :]

    return out, attn

def npy_loader_phonemes(path):
    feat = np.load(path)

    txt = feat['phonemes'].astype('int64')
    txt = torch.from_numpy(txt)

    audio = feat['audio_features']
    audio = torch.from_numpy(audio)

    return txt, audio, feat

# %% [markdown]
# # CSML MSc Project
# ## Speaker-Adaptive Neural Text-to-Speech Synthesis
#
# ### with Papercup

# %% [markdown]
# ### Agenda:
# * Summary of progress so far
# * Proposed research agenda
# * Feedback!
# * Agree next steps & milestones

# %%
Image("/home/ubuntu/loop/logo.png", width=100, height=100)

# %% [markdown]
# # I) Progress So Far

# %% [markdown]
# * **Started with Papercup last week**
#     - Plan is to be based with them throughout the summer

# %% [markdown]
# * **Set up tech/workflow tools**
#     - AWS, notebooks, PyCharm

# %% [markdown]
# * **Literature review**
#     * Using Mendeley

# %% [markdown]
# * **Benchmark implementation up & running**
#     - Data source, code, sensible results

# %% [markdown]
# * **Proposed research agenda**

# %% [markdown]
# #### My notes
# * Good initial progress
# * Built some momentum
# * Need guidance on research agenda
# * What makes a sensible/good project
# * What is expected in terms of write up
# <hr>

# %% [markdown]
# # II) Literature Review

# %% [markdown]
#  * **1) Domain background**
#     - Computational linguistics, phonemes, signal processing (spectrograms, MFCCs)

# %% [markdown]
# * **2) Traditional approaches to TTS**
#     - concatenative vs. statistical parametric

# %% [markdown]
# * **3) Sequence to sequence approaches to TTS**
#     - Tacotron (WaveNet), DeepVoice, VoiceLoop...
#     - Single speaker vs. multi-speaker (speaker embeddings spaces)

# %% [markdown]
# * ** 4) Wider literature on representation learning**
#     - VAE: conditional VAE, VQVAE, BetaVAE
#     - GAN: icGAN, infoGAN

# %% [markdown]
#     - Differ in how 'end-to-end' they are (text features, audio features, vocoder)
#
#     - Fader networks
#     - Style transfer
#
#     - Supervised vs. unsupervised

# %% [markdown]
# #### Notes
# * Could do various projects in this context...
# * Extend framework to new dataset (or new language)
# * Or in-the-wild dataset
# * Modifications to existing frames (e.g. loss functions)
# * My project:

# %% [markdown]
# # III) Proposed Research Agenda
# * Start with a benchmark model: **<font color=red>VoiceLoop multi-speaker using VCTK</font>**
#     - Released VoiceLoop uses 22 speakers: need to build sim on a larger subset of VCTK

# %% [markdown]
# * Investigate speaker embeddings in the benchmark
#     - PCA/T-SNE; Interpolation; Learning an embedding for an unseen speaker

# %% [markdown]
# * Supervised extension to speaker embeddings: **<font color=red>Fader Networks</font>**
#     - Trained to disentangle latent representation of input from labelled attributes
#     - Adversarial network that tries to identify labels of an example given the latent representation

# %% [markdown]
# * Unsupervised extentsion to speaker embeddings: **<font color=red>BetaVAE</font>**
#     - Hyperparameter that trades off reconstruction accuracy vs. distentangled latent factors
#     - Does it learn the factors from the supervised case (gender, accent) but without using labels?
#     - Does it learn additional factors e.g. depth of voice?

# %% [markdown]
# * Use techniques from 4) to learn and control speaker characterstics
#    - Use labels supplied in the VCTK dataset
#
#       - Add term to loss function to force speaker embedding layer to learn a representation from which adversarial network can't recover the labelsEncoder-decoder

# %% [markdown]
# # IV) Benchmark VoiceLoop Implementation
# * Facebook AI Research published the original VoiceLoop paper in July 2017
# * Sequence to sequence model with attention
#     - Inputs: `(phonemes, speaker_id)`
#     - Targets: `WORLD features`
#     - Encoder: lookup up tables for phonemes and speakers
#     - Attention: Gaussian mixture model
#     - Decoder: FIFO memory buffer
# * VCTK dataset

# %% [markdown]
# ## VCTK Dataset
# * Multispeaker English voice dataset
# * ~400 sentences per speaker
# * Each example consists of `(wav_file, text_transcript, speaker_id)`
# * University of Edinburgh's Cente for Speech Technology Research

# %%
speaker_info = get_vtck_speaker_info()

# %%
print "Number of Speakers: " + str(len(speaker_info))
display(speaker_info.iloc[10:25])
# Out:
# Number of Speakers: 108
#       id  age gender        accents            region
# 236  236   23      F        English        Manchester
# 237  237   22      M       Scottish              Fife
# 238  238   22      F  NorthernIrish           Belfast
# 239  239   22      F        English        SW England
# 240  240   21      F        English  Southern England
# 241  241   21      M       Scottish             Perth
# 243  243   22      M        English            London
# 244  244   22      F        English        Manchester
# 245  245   25      M          Irish            Dublin
# 246  246   22      M       Scottish           Selkirk
# 247  247   22      M       Scottish            Argyll
# 248  248   23      F         Indian
# 249  249   22      F       Scottish          Aberdeen
# 250  250   22      F        English        SE England
# 251  251   26      M         Indian

# %%
# plot descriptive statistics of speakers
plt.figure(figsize=(15,10))

for i, c in enumerate(['age', 'gender', 'accents']):
    plt.subplot(2,2,i+1)
    speaker_info[c].value_counts().sort_index().plot(kind='barh', color='red', grid=True, title=c)
    plt.xlabel('count')
    plt.ylabel(c)
    
plt.savefig(os.path.join(save_folder, 'vctk_descriptive_age_etc'))

# %%
display(speaker_info.iloc[10:25])

# set speaker here
speaker_id = 301
# Out:
#       id  age gender        accents            region
# 236  236   23      F        English        Manchester
# 237  237   22      M       Scottish              Fife
# 238  238   22      F  NorthernIrish           Belfast
# 239  239   22      F        English        SW England
# 240  240   21      F        English  Southern England
# 241  241   21      M       Scottish             Perth
# 243  243   22      M        English            London
# 244  244   22      F        English        Manchester
# 245  245   25      M          Irish            Dublin
# 246  246   22      M       Scottish           Selkirk
# 247  247   22      M       Scottish            Argyll
# 248  248   23      F         Indian
# 249  249   22      F       Scottish          Aberdeen
# 250  250   22      F        English        SE England
# 251  251   26      M         Indian

# %%
speaker_info.to_csv(os.path.join(save_folder, 'vctk_meta_data'), index=False)

# %%
# export all transcripts to .csv
for speaker_id in speaker_info.id:
    txt_folder = os.path.join(vctk_folder, 'txt/p' + str(speaker_id))
    txt_files = sorted(gl.glob(os.path.join(txt_folder, '*.txt')))

    s = []
    d = dict()
    for t in txt_files:
        f = open(t, 'r')
        txt = f.read()
        s.append(os.path.basename(t).replace('.txt', '') + ': ' + txt)
        #s.append(f.read())
        #print f.read()
        d[os.path.basename(t).replace('.txt', '')] = txt
        f.close()
        
    # export all transcripts to .csv
    tmp = pd.DataFrame([d]).T
    tmp.columns = {'Transcript'}
    tmp.to_csv(os.path.join(save_folder, 'transcript_' + str(speaker_id)))
    
    print "Done for: " + str(speaker_id)
# Out:
# Done for: 225
# Done for: 226
# Done for: 227
# Done for: 228
# Done for: 229
# Done for: 230
# Done for: 231
# Done for: 232
# Done for: 233
# Done for: 234
# Done for: 236
# Done for: 237
# Done for: 238
# Done for: 239
# Done for: 240
# Done for: 241
# Done for: 243
# Done for: 244
# Done for: 245
# Done for: 246
# Done for: 247
# Done for: 248
# Done for: 249
# Done for: 250
# Done for: 251
# Done for: 252
# Done for: 253
# Done for: 254
# Done for: 255
# Done for: 256
# Done for: 257
# Done for: 258
# Done for: 259
# Done for: 260
# Done for: 261
# Done for: 262
# Done for: 263
# Done for: 264
# Done for: 265
# Done for: 266
# Done for: 267
# Done for: 268
# Done for: 269
# Done for: 270
# Done for: 271
# Done for: 272
# Done for: 273
# Done for: 274
# Done for: 275
# Done for: 276
# Done for: 277
# Done for: 278
# Done for: 279
# Done for: 281
# Done for: 282
# Done for: 283
# Done for: 284
# Done for: 285
# Done for: 286
# Done for: 287
# Done for: 288
# Done for: 292
# Done for: 293
# Done for: 294
# Done for: 295
# Done for: 297
# Done for: 298
# Done for: 299
# Done for: 300
# Done for: 301
# Done for: 302
# Done for: 303
# Done for: 304
# Done for: 305
# Done for: 306
# Done for: 307
# Done for: 308
# Done for: 310
# Done for: 311
# Done for: 312
# Done for: 313
# Done for: 314
# Done for: 315
# Done for: 316
# Done for: 317
# Done for: 318
# Done for: 323
# Done for: 326
# Done for: 329
# Done for: 330
# Done for: 333
# Done for: 334
# Done for: 335
# Done for: 336
# Done for: 339
# Done for: 340
# Done for: 341
# Done for: 343
# Done for: 345
# Done for: 347
# Done for: 351
# Done for: 360
# Done for: 361
# Done for: 362
# Done for: 363
# Done for: 364
# Done for: 374
# Done for: 376

# %%
display(speaker_info)

# set speaker here
speaker_id = 255
# Out:
#       id  age gender        accents            region
# 225  225   23      F        English  Southern England
# 226  226   22      M        English            Surrey
# 227  227   38      M        English           Cumbria
# 228  228   22      F        English  Southern England
# 229  229   23      F        English  Southern England
# 230  230   22      F        English  Stockton-on-tees
# 231  231   23      F        English  Southern England
# 232  232   23      M        English  Southern England
# 233  233   23      F        English     Staffordshire
# 234  234   22      F       Scottish     West Dumfries
# 236  236   23      F        English        Manchester
# 237  237   22      M       Scottish              Fife
# 238  238   22      F  NorthernIrish           Belfast
# 239  239   22      F        English        SW England
# 240  240   21      F        English  Southern England
# 241  241   21      M       Scottish             Perth
# 243  243   22      M        English            London
# 244  244   22      F        English        Manchester
# 245  245   25      M          Irish            Dublin
# 246  246   22      M       Scottish           Selkirk
# 247  247   22      M       Scottish            Argyll
# 248  248   23      F         Indian
# 249  249   22      F       Scottish          Aberdeen
# 250  250   22      F        English        SE England
# 251  251   26      M         Indian
# 252  252   22      M       Scottish         Edinburgh
# 253  253   22      F          Welsh           Cardiff
# 254  254   21      M        English            Surrey
# 255  255   19      M       Scottish          Galloway
# 256  256   24      M        English        Birmingham
# ..   ...  ...    ...            ...               ...
# 311  311   21      M       American              Iowa
# 312  312   19      F       Canadian          Hamilton
# 313  313   24      F          Irish       County Down
# 314  314   26      F   SouthAfrican         Cape Town
# 315  315   18      M       American       New England
# 316  316   20      M       Canadian           Alberta
# 317  317   23      F       Canadian          Hamilton
# 318  318   32      F       American              Napa
# 323  323   19      F   SouthAfrican          Pretoria
# 326  326   26      M     Australian    English Sydney
# 329  329   23      F       American
# 330  330   26      F       American
# 333  333   19      F       American           Indiana
# 334  334   18      M       American           Chicago
# 335  335   25      F     NewZealand           English
# 336  336   18      F   SouthAfrican      Johannesburg
# 339  339   21      F       American      Pennsylvania
# 340  340   18      F          Irish            Dublin
# 341  341   26      F       American              Ohio
# 343  343   27      F       Canadian           Alberta
# 345  345   22      M       American           Florida
# 347  347   26      M   SouthAfrican      Johannesburg
# 351  351   21      F  NorthernIrish             Derry
# 360  360   19      M       American        New Jersey
# 361  361   19      F       American        New Jersey
# 362  362   29      F       American
# 363  363   22      M       Canadian           Toronto
# 364  364   23      M          Irish           Donegal
# 374  374   28      M     Australian           English
# 376  376   22      M         Indian
#
# [108 rows x 5 columns]

# %%
txt_folder = os.path.join(vctk_folder, 'txt/p' + str(speaker_id))
txt_files = sorted(gl.glob(os.path.join(txt_folder, '*.txt')))

s = []
d = dict()
for t in txt_files:
    f = open(t, 'r')
    txt = f.read()
    s.append(os.path.basename(t).replace('.txt', '') + ': ' + txt)
    #s.append(f.read())
    #print f.read()
    d[os.path.basename(t).replace('.txt', '')] = txt
    f.close()
    
#pd.DataFrame(s, [os.path.basename(t).replace('.txt', '') for t in txt_files])
display(s)


# set sample here
sample_id = 367
# Out:
# ['p255_001: Please call Stella.  \n',
#  'p255_002: Ask her to bring these things with her from the store.  \n',
#  'p255_003: Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob.  \n',
#  'p255_004: We also need a small plastic snake and a big toy frog for the kids.  \n',
#  'p255_005: She can scoop these things into three red bags, and we will go meet her Wednesday at the train station. \n',
#  'p255_006: When the sunlight strikes raindrops in the air, they act as a prism and form a rainbow. \n',
#  'p255_007: The rainbow is a division of white light into many beautiful colors. \n',
#  'p255_008: These take the shape of a long round arch, with its path high above, and its two ends apparently beyond the horizon. \n',
#  'p255_009: There is , according to legend, a boiling pot of gold at one end. \n',
#  'p255_010: People look, but no one ever finds it. \n',
#  'p255_011: When a man looks for something beyond his reach, his friends say he is looking for the pot of gold at the end of the rainbow. \n',
#  'p255_012: Throughout the centuries people have explained the rainbow in various ways. \n',
#  'p255_013: Some have accepted it as a miracle without physical explanation. \n',
#  'p255_014: To the Hebrews it was a token that there would be no more universal floods. \n',
#  'p255_015: The Greeks used to imagine that it was a sign from the gods to foretell war or heavy rain. \n',
#  'p255_016: The Norsemen considered the rainbow as a bridge over which the gods passed from earth to their home in the sky. \n',
#  'p255_017: Others have tried to explain the phenomenon physically. \n',
#  "p255_018: Aristotle thought that the rainbow was caused by reflection of the sun's rays by the rain. \n",
#  'p255_019: Since then physicists have found that it is not reflection, but refraction by the raindrops which causes the rainbows. \n',
#  'p255_020: Many complicated ideas about the rainbow have been formed. \n',
#  'p255_021: The difference in the rainbow depends considerably upon the size of the drops, and the width of the colored band increases as the size of the drops increases. \n',
#  'p255_022: The actual primary rainbow observed is said to be the effect of super-imposition of a number of bows. \n',
#  'p255_023: If the red of the second bow falls upon the green of the first, the result is to give a bow with an abnormally wide yellow band, since red and green light when mixed form yellow. \n',
#  'p255_024: This is a very common type of bow, one showing mainly red and yellow, with little or no green or blue.\n',
#  'p255_025: He has not been named.\n',
#  'p255_026: We have to pull together, or we will hang apart.\n',
#  'p255_027: They should be so lucky.\n',
#  'p255_028: We want to ensure that the process is entirely transparent.\n',
#  'p255_029: They were described as being in a serious but stable condition yesterday.\n',
#  'p255_030: Life was like a timetable.\n',
#  'p255_031: Mr Ferguson became a minister after seven years as a journalist.\n',
#  "p255_032: Then, suddenly, they weren't.\n",
#  "p255_033: It can't just be a cynical marketing exercise.\n",
#  'p255_034: In both cases, I suffered a fiasco.\n',
#  'p255_035: Two other men, including the taxi driver, were wounded in the attack.\n',
#  'p255_036: We do not expect any surplus.\n',
#  'p255_037: Dancing was her life.\n',
#  'p255_038: It is great to have this beautiful new site in wonderful countryside.\n',
#  'p255_039: It is a memorial.\n',
#  'p255_040: Mexico City was a wonderful experience.\n',
#  'p255_041: But it might have done.\n',
#  'p255_042: The whole of southern Africa is in the grip of Aids.\n',
#  'p255_043: People were determined to change the Government in the last election.\n',
#  'p255_044: I felt really good until Friday.\n',
#  'p255_045: She looked so young.\n',
#  'p255_046: Life is good.\n',
#  'p255_047: No-one has appeared in court in relation to her death.\n',
#  'p255_048: I got a great response from the players, as I had expected.\n',
#  'p255_049: We were surprised to see the photograph.\n',
#  'p255_050: It was not hard to feel some sympathy for Baxter yesterday.\n',
#  'p255_051: Mr Blair is the problem in Scotland, not the solution.\n',
#  "p255_052: It's very odd.\n",
#  'p255_053: Because we do not need it.\n',
#  "p255_054: That's the truth.\n",
#  'p255_055: My mother is a widow.\n',
#  'p255_057: George Robertson described the plan as an outrageous and disgraceful decision.\n',
#  'p255_058: There will be tough opponents to this report.\n',
#  'p255_059: Equity declined to comment.\n',
#  'p255_060: Hopefully, we have learned a lot from that game.\n',
#  'p255_061: Over time, with patience and precision, the terrorists will be pursued.\n',
#  'p255_062: There was a tremendous amount of anger and frustration in that music.\n',
#  'p255_063: We should have known.\n',
#  'p255_064: We welcome the decision of Mr Byers.\n',
#  'p255_065: The end result is precisely the same.\n',
#  'p255_066: It came as a surprise because my job is to go backwards.\n',
#  'p255_067: There is an element of racism in Scotland.\n',
#  'p255_068: There could be a way back.\n',
#  'p255_069: He highlighted a lack of staff.\n',
#  'p255_070: Then followed a bout of flu.\n',
#  'p255_071: Ferguson should take note.\n',
#  'p255_072: It works for us.\n',
#  'p255_073: He is now resident in England.\n',
#  "p255_074: I've got the shirt.\n",
#  'p255_075: Two Israeli cabinet ministers were in the building at the time.\n',
#  'p255_076: What has changed?\n',
#  'p255_077: However, we will obviously keep the matter under review.\n',
#  'p255_078: Last week, he was taken into hospital.\n',
#  'p255_079: He is driven.\n',
#  'p255_080: Nothing is yet confirmed.\n',
#  'p255_081: We have other options.\n',
#  'p255_082: We want to know about the policy.\n',
#  'p255_083: It just shows the arrogance of Labour and the Liberal Democrats.\n',
#  "p255_084: It's never too late.\n",
#  'p255_085: Florida is the pivotal state in the nation.\n',
#  'p255_086: We do not get that impression now.\n',
#  'p255_087: It is a lifeline.\n',
#  'p255_088: However, it did not end that way.\n',
#  "p255_089: They've got to account for it.\n",
#  'p255_090: That deal will be decided under the existing rules.\n',
#  'p255_091: Until you hit the big games.\n',
#  'p255_092: We could not get any possession.\n',
#  'p255_093: If you could find it.\n',
#  'p255_094: The selection process is still at a very early stage.\n',
#  'p255_095: It is a delight on every level.\n',
#  'p255_096: Get to know him.\n',
#  'p255_097: May not have been at fault?\n',
#  'p255_098: I had a ball today.\n',
#  'p255_099: Two of the team became ill.\n',
#  'p255_100: That time is not now, however.\n',
#  'p255_101: Oil embargo endorsed.\n',
#  'p255_102: Scotland were beaten again.\n',
#  'p255_103: Before the game we went for a pint.\n',
#  'p255_104: Further protests are likely.\n',
#  'p255_105: According to the criteria, he is qualified for Scotland.\n',
#  'p255_106: It is still too early for any likely contenders to have emerged.\n',
#  'p255_107: He leaves a wife, a son and a daughter.\n',
#  'p255_108: He was jailed for a year.\n',
#  'p255_109: I came to complete.\n',
#  'p255_110: Naturally, it was not difficult to find support for these proposals.\n',
#  'p255_111: We have to look at everything before we make any final decision.\n',
#  'p255_112: Maybe this battle has been.\n',
#  "p255_113: I'm delighted about that.\n",
#  'p255_114: Until the weekend he was minister for social justice.\n',
#  'p255_115: I joined a group.\n',
#  'p255_116: Does this mean.\n',
#  'p255_117: They could not ignore the will of parliament, he claimed.\n',
#  'p255_118: That was the lesson to be learned from the European Championships.\n',
#  'p255_119: Strathclyde Police are expected to make an announcement next month.\n',
#  'p255_120: An announcement on his replacement is expected within three weeks.\n',
#  "p255_121: I can't even get into the A team.\n",
#  'p255_122: Wednesday night was a difficult time for Britton.\n',
#  'p255_123: Child abuse is a dreadful thing.\n',
#  'p255_124: His son has been travelling with the Tartan Army for years.\n',
#  'p255_125: Next season for every manager is a long time away.\n',
#  'p255_126: We have the experience, the courses, and an abundance of confidence.\n',
#  'p255_127: It will be too hot.\n',
#  'p255_128: The role was perfect for Russell.\n',
#  'p255_129: If not, a deal could take many months.\n',
#  'p255_130: My main concern is that public health is not put at risk.\n',
#  'p255_131: Our intentions are real.\n',
#  'p255_132: It is also well received.\n',
#  'p255_133: The Scottish Socialist party is also expected to attend.\n',
#  'p255_134: We never said that we would walk through the third division.\n',
#  'p255_135: Ms McNeill was killed on impact.\n',
#  'p255_136: On Friday, the headteacher and deputy headteacher appeared at the door.\n',
#  'p255_137: I saw some terrible things.\n',
#  "p255_138: It's a question of fashion.\n",
#  'p255_139: Suddenly, the Fir Park side were in disarray.\n',
#  'p255_140: In this case, the farmer had actually given permission.\n',
#  'p255_141: We have got to get it right.\n',
#  'p255_142: Wallace was a prisoner of war.\n',
#  'p255_143: The way he took his second goal was brilliant.\n',
#  'p255_144: Who would be right?\n',
#  'p255_145: She died at her home.\n',
#  'p255_146: Alice, the girl, was said by doctors to be in good condition.\n',
#  'p255_147: I was awful.\n',
#  'p255_148: The idea is simple.\n',
#  'p255_149: It is like a football team.\n',
#  'p255_150: It would be a last resort.\n',
#  'p255_151: He sets the nature of his Parliament in simple, realistic context.\n',
#  'p255_152: It is not just about pay.\n',
#  "p255_153: The home side didn't stand a chance.\n",
#  'p255_154: We shall not be moved.\n',
#  'p255_155: The weaknesses are few.\n',
#  'p255_156: The amount of energy in a tornado is enormous.\n',
#  'p255_157: Crucially, though, United were still alive.\n',
#  'p255_158: The first victory made a huge difference to my career.\n',
#  "p255_159: There's a sense of excess in the novel.\n",
#  'p255_160: Work has started.\n',
#  "p255_161: It's a problem but it cannot become an excuse.\n",
#  'p255_162: And sooner than we may think.\n',
#  'p255_163: The weather affected the other two games in Fife.\n',
#  'p255_164: It is so unfair.\n',
#  'p255_165: I will tell you.\n',
#  'p255_166: Eight months later, he was dead.\n',
#  'p255_167: It could take years for the tunnel to be reopened.\n',
#  'p255_168: We have to move forward.\n',
#  'p255_169: However, the French government has a major dilemma on its hands.\n',
#  'p255_170: I lost my head.\n',
#  'p255_171: That must be left to the Parole Board.\n',
#  'p255_172: He is keen to stay in public service.\n',
#  'p255_173: You are not going in blind.\n',
#  'p255_174: They will do their own thing.\n',
#  'p255_175: As far as we were concerned the deal with Kennedy was dead.\n',
#  'p255_176: You had to go and see him.\n',
#  'p255_177: Waiting times for these services are too long.\n',
#  'p255_178: A helpline number is published at the end of this article.\n',
#  'p255_179: His team management was protective.\n',
#  'p255_180: Is Saddam a threat?\n',
#  'p255_181: The jury is still out.\n',
#  'p255_182: We wanted it left for a wee while.\n',
#  'p255_183: However, the figures were disputed by the Scottish Prison Service.\n',
#  'p255_184: And I saw the light!\n',
#  "p255_185: The event was held in the council's headquarters in Hamilton.\n",
#  "p255_186: I've been in two finals, and I've got a medal.\n",
#  'p255_187: Tony had arrived.\n',
#  'p255_188: It is the whole package.\n',
#  'p255_189: I have the first six months of next season to prove myself.\n',
#  'p255_190: The goals were good.\n',
#  'p255_191: There is no point in looking any further.\n',
#  'p255_192: And she is a successful actor with three decades of experience.\n',
#  'p255_193: Four policemen were wounded.\n',
#  'p255_194: Everyone is in favour of the need for welfare reform in general.\n',
#  'p255_195: The award to Senator Mitchell was announced by the Foreign Office.\n',
#  'p255_196: They are now divorced.\n',
#  'p255_197: I cannot say too much about them.\n',
#  'p255_198: It was only later that the condition was diagnosed.\n',
#  'p255_199: However, this idea is never developed.\n',
#  'p255_200: It is a farce.\n',
#  'p255_201: I am totally surprised.\n',
#  'p255_202: We must keep our feet on the ground.\n',
#  'p255_203: However, he said the money had not been wasted.\n',
#  'p255_204: The confidence is low, but it is a difficult thing to understand.\n',
#  'p255_205: He has a lot of experience as captain in his career.\n',
#  'p255_206: The sisters also became the top two players in the world.\n',
#  'p255_207: The album was widely expected to be a commercial disaster.\n',
#  "p255_208: It's just awful.\n",
#  "p255_209: It's all about money, money, money.\n",
#  'p255_210: It was worth a photograph.\n',
#  'p255_211: We will give a formal response to the report in due course.\n',
#  "p255_212: We're not seeing an image of the person, he said.\n",
#  "p255_213: We'll have to work hard today.\n",
#  'p255_214: He knows a lot.\n',
#  'p255_215: That is an important part of our role.\n',
#  'p255_216: Her home is perhaps a couple of miles from the town centre.\n',
#  'p255_217: I had relied on him.\n',
#  'p255_218: I had decided to quit the show.\n',
#  'p255_219: His third goal was superb.\n',
#  "p255_220: It's been a good year.\n",
#  'p255_221: So far, the scheme has not been used in Scotland.\n',
#  "p255_222: It's not ideal.\n",
#  'p255_223: The FBI could become involved.\n',
#  'p255_224: A final decision will be taken by First Minister Donald Dewar.\n',
#  'p255_225: The attacker has been put in foster care.\n',
#  'p255_226: His death was a tragic accident.\n',
#  'p255_227: On a technical level, they were not afraid to play good football.\n',
#  'p255_228: But it was for charity, just a bit of fun.\n',
#  'p255_229: A career as a doctor is on hold.\n',
#  'p255_230: During the communist time they were very privileged.\n',
#  'p255_231: Mental health is a massive issue.\n',
#  'p255_232: We played them off the pitch.\n',
#  'p255_233: Lottery cash is rightly dependent on grassroots approval.\n',
#  'p255_234: Our numbers are small.\n',
#  'p255_235: They are the innocent victims.\n',
#  "p255_236: It's like a basketball.\n",
#  'p255_237: You should always be able to get out in some direction.\n',
#  'p255_238: At the time, he was a living legend.\n',
#  "p255_239: It's the same as Glasgow.\n",
#  'p255_240: Her condition was yesterday described as critical, but stable.\n',
#  'p255_241: It is mainstream.\n',
#  'p255_242: Dewar is certainly under attack from within his own party.\n',
#  'p255_243: We were awful.\n',
#  'p255_244: They had no children.\n',
#  'p255_245: It is set in Paris.\n',
#  'p255_246: It is not the message alone.\n',
#  "p255_247: It's quite a line-up!\n",
#  'p255_248: It has been declared.\n',
#  'p255_249: The perception is that we do not care about social issues.\n',
#  'p255_250: We have a free vote on these things in our party.\n',
#  'p255_251: It would appear that it has not been a problem.\n',
#  "p255_252: It's only fair.\n",
#  'p255_253: He repeated his call for an inquiry into the police response.\n',
#  'p255_254: Chambers said he would accept the place.\n',
#  'p255_255: His body was never found.\n',
#  "p255_256: There's the mix.\n",
#  'p255_257: We need to move away from the culture of long hours.\n',
#  "p255_258: I can't get a job.\n",
#  'p255_259: He was my big brother, my father, my grandfather.\n',
#  'p255_260: For the Scottish judges, the affair is very delicate and unique.\n',
#  'p255_261: That was a bonus, but it was not the main objective.\n',
#  'p255_262: However, it is understood that offers of further payments are unlikely.\n',
#  'p255_263: It will now relate to all public bodies in Scotland.\n',
#  'p255_264: I am very angry.\n',
#  'p255_265: They must play for each other.\n',
#  'p255_266: He can do everything.\n',
#  'p255_267: An appeal against the sentence was dismissed the following year.\n',
#  'p255_268: This court has made an order which has not been observed.\n',
#  'p255_269: The work between the musicians and the fire is very important.\n',
#  'p255_270: He thought he had a month to cross the street.\n',
#  "p255_271: It's all change on the music scene in Manchester.\n",
#  'p255_272: They want to shut the Scottish Office.\n',
#  'p255_273: This is a question of Islam.\n',
#  'p255_274: It looks as though he will be right.\n',
#  'p255_275: He was popular.\n',
#  'p255_276: I am pleased with the result, as it was a possible upset.\n',
#  'p255_277: Similar measures are expected in England and Wales.\n',
#  'p255_278: It depends on the internal discussions in the Ministry of Defence.\n',
#  'p255_279: Everything will fall into place, it should be fine.\n',
#  'p255_280: One knows the feeling.\n',
#  'p255_281: He promised to lead from the front in battle for entry.\n',
#  'p255_282: In essence, the teaching profession has a choice.\n',
#  'p255_283: Several other pupils and staff were seriously injured in the accident.\n',
#  'p255_284: For the moment, that is the result of the X-ray.\n',
#  'p255_285: This is a national crisis.\n',
#  'p255_286: The death toll included five children.\n',
#  'p255_287: My body is clearly capable.\n',
#  'p255_288: So I did.\n',
#  'p255_289: The judges will give a ruling next Wednesday.\n',
#  'p255_290: She said she could not believe that they had run away.\n',
#  'p255_292: These figures are truly awful.\n',
#  "p255_293: It's an issue that will have to be tackled.\n",
#  "p255_294: Plans to celebrate the Queen's Golden Jubilee will proceed.\n",
#  'p255_295: Who can predict?\n',
#  'p255_296: If you can run a computer, you can talk to the world.\n',
#  'p255_297: A new school will be built.\n',
#  'p255_298: I have tonight resigned as member of the European Commission.\n',
#  'p255_299: Last night he was due to hold talks with Arafat.\n',
#  'p255_300: Graeme was prepared.\n',
#  'p255_301: In spite of recent advances, the language is still under threat.\n',
#  'p255_302: He was adamant that he was still ahead on everything that matters.\n',
#  'p255_303: Our task is to complete the picture.\n',
#  'p255_304: they fail to engage.\n',
#  'p255_305: Details of the new vessel were given in London yesterday.\n',
#  'p255_306: The company yesterday refused to comment.\n',
#  'p255_307: The report will go before the Scottish Parliament, probably in early autumn.\n',
#  "p255_308: It's certainly different.\n",
#  'p255_309: Is there on his hands?\n',
#  'p255_310: We have got no money to go anywhere.\n',
#  "p255_311: It's about my time as a guitarist.\n",
#  'p255_312: There is no other solution to congestion in Edinburgh.\n',
#  'p255_313: I never thought it would take this long.\n',
#  'p255_314: In fact, they have the opposite effect.\n',
#  'p255_315: The election is total confusion and chaos.\n',
#  'p255_316: Henman has been warned.\n',
#  'p255_317: It will decide today whether he should be struck off the register.\n',
#  'p255_318: I asked for a positive response and I was given one.\n',
#  'p255_319: For the moment, our position remains the same.\n',
#  'p255_320: Referees are easy targets.\n',
#  'p255_321: There was some merit in that.\n',
#  'p255_322: I came into this world with nothing.\n',
#  "p255_323: That's the law of the land.\n",
#  'p255_324: They will be destroyed.\n',
#  'p255_325: It is a strong case.\n',
#  'p255_326: My view has now completely changed.\n',
#  'p255_327: The police have to act to help them.\n',
#  'p255_328: We agreed to disagree.\n',
#  'p255_329: On Thursday, Mr Blair will address the Institute of Public Policy Research.\n',
#  'p255_330: It could have gone either way.\n',
#  'p255_331: It is a time bomb.\n',
#  "p255_332: I'd like to take the plunge.\n",
#  'p255_333: It can be halted.\n',
#  'p255_334: Work is under way to create a studio in Inverness.\n',
#  "p255_335: They haven't got a hope.\n",
#  'p255_336: Gaelic provision continued to be good.\n',
#  "p255_337: That's not eviction because he is not a tenant.\n",
#  'p255_338: The Scottish Prison Service said it could not comment on the visit.\n',
#  'p255_339: Today, we begin to answer that question.\n',
#  'p255_340: Look at the witnesses.\n',
#  'p255_341: Nobody else was with me.\n',
#  'p255_342: A change in that position would require a decision by the council.\n',
#  'p255_343: That is the very reason why it was so vital.\n',
#  'p255_344: In the early days, I was obsessed with working in the theatre.\n',
#  'p255_345: This is a friendly match?\n',
#  'p255_346: I was pleased to be back on the podium in Brazil.\n',
#  'p255_347: Despite his senior position, he did not know in advance.\n',
#  'p255_348: On the front line beyond the bridge the scene was utter chaos.\n',
#  'p255_349: That is a break with tradition.\n',
#  'p255_350: I kept going for her.\n',
#  'p255_351: The Scottish Parliament should set an example for Westminster to follow.\n',
#  "p255_352: He's very explosive.\n",
#  'p255_353: I was in the train station overnight.\n',
#  'p255_354: It benefits the whole family.\n',
#  'p255_355: It was one in the afternoon.\n',
#  'p255_356: To do so he reckons that a good opening result is essential.\n',
#  'p255_357: We will be homeless.\n',
#  'p255_358: It was fit for royalty.\n',
#  'p255_359: We are looking for perfection.\n',
#  'p255_360: It should be an enjoyable and challenging period of their lives.\n',
#  'p255_361: Obviously, we were pretty close in a couple of games.\n',
#  'p255_362: I have got a wife to feed.\n',
#  'p255_363: I wanted to help the poor people in Edinburgh.\n',
#  'p255_364: Not so, it seems.\n',
#  'p255_365: Tell it like it was?\n',
#  'p255_366: For one veteran, the memories remain vivid.\n',
#  'p255_367: Anything is possible in football and we can beat Celtic again.\n',
#  'p255_368: He put some colour into Scottish history.\n',
#  'p255_369: I decided to tell a bit of the story about myself.\n',
#  'p255_370: They received a reply from their own managers.\n',
#  'p255_371: By that time, however, it was already too late.\n',
#  'p255_372: Yesterday the company reported a further downturn in profits.\n',
#  "p255_373: It's a long process.\n",
#  'p255_374: Not because they want to sing about something.\n',
#  'p255_375: He could not be contacted for further comment yesterday.\n',
#  'p255_376: Colour was at the core of his life.\n',
#  "p255_377: He's delighted, too, with the new premises.\n",
#  'p255_378: It was as if it was all happening at a garden party.\n',
#  'p255_379: Hopefully, it will come from someone on our side.\n',
#  'p255_380: The casualties were not named.\n',
#  'p255_381: I looked again at its vision for a Scottish Parliament.\n']

# %%
display_vctk_sample(speaker_id, sample_id, os.path.join(save_folder, 'wavplot_' + str(speaker_id) + '_' + str(sample_id)))
# Out:
#       id  age gender   accents    region
# 255  255   19      M  Scottish  Galloway
# Anything is possible in football and we can beat Celtic again.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# VoiceLoop only uses the speakers with American accents
speaker_info[speaker_info.accents == 'American']
# Out:
#       id  age gender   accents          region
# 294  294   33      F  American   San Francisco
# 297  297   20      F  American        New York
# 299  299   25      F  American      California
# 300  300   23      F  American      California
# 301  301   23      F  American  North Carolina
# 305  305   19      F  American    Philadelphia
# 306  306   21      F  American        New York
# 308  308   18      F  American         Alabama
# 310  310   21      F  American       Tennessee
# 311  311   21      M  American            Iowa
# 315  315   18      M  American     New England
# 318  318   32      F  American            Napa
# 329  329   23      F  American
# 330  330   26      F  American
# 333  333   19      F  American         Indiana
# 334  334   18      M  American         Chicago
# 339  339   21      F  American    Pennsylvania
# 341  341   26      F  American            Ohio
# 345  345   22      M  American         Florida
# 360  360   19      M  American      New Jersey
# 361  361   19      F  American      New Jersey
# 362  362   29      F  American

# %% [markdown]
# - quick descriptive stats
# - show example of labels, say we can use these
# - show some examples

# %% [markdown]
# ## WORLD Features
# * WORLD is an open-source speech synthesis system that:
#     - 1) Can **analyse** speech data into WORLD features
#     - 2) Can **synthesise** WORLD features into synthesized speech

# %%
speaker_id = 301
sample_id = 117
# load pre-calculated WORLD features
feats = load_pre_calc_features(speaker_id, sample_id)

# %%
plot_lf0_etc(feats, os.path.join(save_folder, 'world_feats_' + str(speaker_id) + '_' + str(sample_id)))

# %% [markdown]
# #### Original VCTK Sample

# %%
speaker_id = 339
sample_id = 117

play_vctk_sample(speaker_id, sample_id, os.path.join(save_folder, 'orig_' + str(speaker_id) + '_' + str(sample_id)))
# Out:
#       id  age gender   accents        region
# 339  339   21      F  American  Pennsylvania
# There are exciting days ahead.
# ih t ih z r ih l iy g uh d n uw z
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Synthesized Voice Using WORLD Features

# %%
# load pre-calculated WORLD features
feats = load_pre_calc_features(speaker_id, sample_id)
    
# synthesize sample from features and listen to the resulting .wav file
rate_synth, wav_data_synth = play_synthesized_features(feats, os.path.join(save_folder, 'synth_' + str(speaker_id) + '_' + str(sample_id)))
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete /home/ubuntu/msc-project-master/msc-project-master/docs/master/synth_339_117.wav.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Benchmark VoiceLoop Results

# %%
speaker_list_vctk = [294, 297, 299, 300, 301, 305, 306, 308, 310, 311, 318, 329, 330, 333, 334, 339, 341, 345, 360, 361, 362]
speaker_lookup = dict([(x, y) for x, y in enumerate(speaker_list_vctk)])

# %%
def get_npz_file(loop_speaker_id, sample_id):
    # Lookup dict from VCTK speaker IDs to the IDs used inside VoiceLoop
    # should really pick this up from the checkpoints, but it's convenient to have it available before/without a checkpoint being defined
    speaker_list_vctk = [294, 297, 299, 300, 301, 305, 306, 308, 310, 311, 318, 329, 330, 333, 334, 339, 341, 345, 360, 361, 362]
    speaker_lookup = dict([(x, y) for x, y in enumerate(speaker_list_vctk)])

    # load VCTK speaker_info metadata
    speaker_info = get_vtck_speaker_info()
    #speaker_info[speaker_info.id.isin(speaker_lookup.values())]
    tmp = pd.DataFrame.from_dict(speaker_lookup, orient='index', columns=['id'])
    #pd.merge(speaker_info, tmp)

    vctk_source_speaker_id = int(speaker_lookup[loop_speaker_id])
    npz_file= 'p' + str(vctk_source_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz'

    # display/listen to the VCTK sample
    #print "Original VCTK .wav File"
    #play_vctk_sample(vctk_source_speaker_id, sample_id)
    
    return npz_file

# %%
def play_vctk_version_loop_id(loop_speaker_id, sample_id):
    # Lookup dict from VCTK speaker IDs to the IDs used inside VoiceLoop
    # should really pick this up from the checkpoints, but it's convenient to have it available before/without a checkpoint being defined
    speaker_list_vctk = [294, 297, 299, 300, 301, 305, 306, 308, 310, 311, 318, 329, 330, 333, 334, 339, 341, 345, 360, 361, 362]
    speaker_lookup = dict([(x, y) for x, y in enumerate(speaker_list_vctk)])

    # load VCTK speaker_info metadata
    speaker_info = get_vtck_speaker_info()
    #speaker_info[speaker_info.id.isin(speaker_lookup.values())]
    tmp = pd.DataFrame.from_dict(speaker_lookup, orient='index', columns=['id'])
    #pd.merge(speaker_info, tmp)

    vctk_source_speaker_id = int(speaker_lookup[loop_speaker_id])
    npz_file= 'p' + str(vctk_source_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz'

    # display/listen to the VCTK sample
    print "Original VCTK .wav File"
    play_vctk_sample(vctk_source_speaker_id, sample_id)
    return npz_file

# %% [markdown]
# #### Generate samples from a model checkpoint...

# %%
# generate based on an existing VCTK sample
source_speaker_id = 12
sample_id = 230
text = ''

# speaker id to use for VoiceLoop generation
gen_speaker_id = 9

# model checkpoint
checkpoint = 'checkpoints/vctk-rs/bestmodel.pth'
checkpoint = 'checkpoints/vctk-recover/bestmodel.pth'
checkpoint = 'models/vctk/bestmodel.pth'

output_dir = './'
output_file = 'test.wav'
norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
speaker_info[speaker_info.id==[speaker_lookup[gen_speaker_id]]]

# generate the sample
npz_file =  get_npz_file(source_speaker_id, sample_id)
loop_dict = generate_sample_with_loop(spkr_id=gen_speaker_id, npz=npz_file, text=text, checkpoint=checkpoint)
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p330_230_9.wav.
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p330_230.orig.wav.

# %% [markdown]
# #### 1) Original VCTK sample

# %%
npz_file = play_vctk_version_loop_id(source_speaker_id, sample_id)
# Out:
# Original VCTK .wav File
#       id  age gender   accents region
# 330  330   26      F  American
# We talk about Mr Michael Johnson, and he is awesome.
# s ih n s dh eh n pau dh ey hh ae v f ao l ax n b ay m ao r dh ae n t uw th er d z
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 2) WORLD Features

# %%
# Play WORLD version
IPython.display.display(Audio(loop_dict['output_orig_fname'] + '.wav', autoplay=True))
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 3) VoiceLoop Version

# %%
# listen to sample synthesized from VoiceLoop features
Audio(loop_dict['output_file'] + '.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Attention

# %%
plot_attn(loop_dict['attn'], loop_dict['txt'], NpzFolder(loop_dict['valid_dataset_path']).dict)

# %% [markdown]
# # V) Next Steps
# * Feedback on the research agenda
# * Structure of project report
#     - Literature review: useful or just padding?
# * Next meeting: Fri 29-June (3 weeks)
# * Milestones?
