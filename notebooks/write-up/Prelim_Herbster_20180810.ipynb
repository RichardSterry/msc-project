# %% [markdown]
# # Copy of old notebook so I can steal bits for project write-up
# * Copied from aws-big\Presentation_MarkHerbster_20180608
# * Running in msc-project-master
# * on aws-spot
# * This was originally used as a Jupyter presentation for my first meeting with Mark
# * Going to check I can recreate it and save a few bits for the write-up

# %%
save_folder = '/home/ubuntu/msc-project-master/msc-project-master/docs/master'

# %%
import os
import pandas as pd
from IPython.display import Audio
from IPython.display import Image
from IPython.display import SVG
from IPython.display import SVG, display
from IPython.core.display import HTML 
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.core.display import Image, display
import matplotlib.cm as cm

from torch.autograd import Variable
from IPython.display import Audio
import IPython.display

import phonemizer
import torch

from data import *
from model import Loop
from utils import generate_merlin_wav

# %%
# %matplotlib inline
import IPython.display
from ipywidgets import interact, interactive, fixed

import numpy as np
import matplotlib.pyplot as plt
import copy
from scipy.io import wavfile
#from scipy.signal import butter, lfilter
#import scipy.ndimage
import os
import argparse

#import spectrograms.spectrogram_utils as su

#import winsound
import pandas as pd

import glob as gl
from IPython.display import display, HTML

import pydub as pyd
import spectrogram as sp
from utils import generate_merlin_wav

from shutil import copyfile

# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/local/lib/python2.7/dist-packages/pydub/utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
os.chdir('/home/ubuntu/loop')
vctk_folder = '/home/ubuntu/VCTK-Corpus/'

# %%
def get_vtck_speaker_info():
    # this is the reference data file that comes as part of VCTK
    speaker_info_file = os.path.join(vctk_folder, 'speaker-info.txt')

   # read file contents
    f = open(speaker_info_file, 'r')
    x = f.readlines()
    f.close()

    # extract column headers
    cols = x[0].lower().split()
    num_cols = len(cols)
    del x[0]
    num_speaker = len(x)

    # parse the data line by line
    d = dict()

    for idx in range(num_speaker):
        this_speaker_id = int(x[idx][:3])
        this_age = int(x[idx][5:7])
        this_gender = x[idx][9]
        residual = x[idx][14:].split()
        this_accent = residual[0]
        this_region = " ".join(residual[1:])

        # add speakers to a dictionary
        d[this_speaker_id] = (this_speaker_id, this_age, this_gender, this_accent, this_region)

    # convert to Pandas datafrae
    speaker_info = pd.DataFrame.from_dict(d, orient='index', columns=cols)
    
    return speaker_info

# %%
from IPython.display import SVG
def show_svg():
    return SVG(url='http://upload.wikimedia.org/wikipedia/en/a/a4/Flag_of_the_United_States.svg')

# %%
def plot_spectrogram(wav_data, rate, title="Original Spectrogram"):
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    data = sp.butter_bandpass_filter(wav_data, lowcut, highcut, rate, order=1)
    #data = butter_bandpass_filter(data, 500, 7500, rate, order=1)
    # Only use a short clip for our demo
    if np.shape(data)[0]/float(rate) > 10:
        data = data[0:rate*10] 
    #print('Length in time (s):' + str(np.shape(data)[0]/float(rate)))

    wav_spectrogram = sp.pretty_spectrogram(wav_data.astype('float64'), fft_size = fft_size, 
                                       step_size = step_size, log = True, thresh = spec_thresh)

    fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,4))
    cax = ax.matshow(np.transpose(wav_spectrogram), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    fig.colorbar(cax)
    plt.title(title)
    #plt.xlim(0, len(wav_data))
    #plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))

def load_pre_calc_features(speaker_id, sample_id):
    pre_calc_features_folder = '/home/ubuntu/loop/data/vctk/numpy_features/'
    pre_calc_features_file = os.path.join(pre_calc_features_folder, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
    feats = np.load(pre_calc_features_file)
    
    return feats

def play_synthesized_features(feats, output_file='test.wav'):
    output_dir = './'
    #output_file = 'test.wav'
    norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
    generate_merlin_wav(feats['audio_features'],
                        output_dir,
                        output_file,
                        norm_path)

    IPython.display.display(IPython.display.Audio(output_file + '.wav', autoplay=True))
    
    rate, wav_data = wavfile.read(output_file + '.wav')  
    
    return rate, wav_data

# %%
def play_vctk_sample(vctk_speaker_id, sample_id, fname=None):
    # raw .wav file
    wav_file = os.path.join(vctk_folder, 'wav48/p' + str(vctk_speaker_id) + '/p' + str(vctk_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.wav')

    # print speaker info
    display(speaker_info[speaker_info['id']==vctk_speaker_id])

    # print text
    txt_file = wav_file.replace("wav48", "txt").replace(".wav", ".txt")
    f = open(txt_file, 'r')
    print(f.read())
    f.close()
    
    x = feats['phonemes']
    #x[x==42] = 0 # for some reason, sometimes there is a phoneme with index=42, which doesn't appear in the dict.
    print " ".join(feats['code2phone'][x])
    
    if fname:
        copyfile(wav_file, fname)

    # play sample
    rate, wav_data = wavfile.read(wav_file)    
    display(IPython.display.Audio(data=wav_data, rate=rate, autoplay=True))

# %%
def plot_lf0_etc(feats, fname=None):
    # plot lf0, vuv and bap features
    plt.figure(figsize=(20, 4))

    plt.subplot(1, 3, 1)
    plt.plot(feats['audio_features'][:, 60])
    plt.title('vuv')
    plt.grid(True)
    plt.ylabel('Normalised Feature')
    plt.xlabel('Frame')

    plt.subplot(1, 3, 2)
    plt.plot(feats['audio_features'][:, 61])
    plt.title('lf0')
    plt.grid(True)
    plt.ylabel('Normalised Feature')
    plt.xlabel('Frame')

    plt.subplot(1, 3, 3)
    plt.plot(feats['audio_features'][:, 62])
    plt.title('bap')
    plt.grid(True)
    plt.ylabel('Normalised Feature')
    plt.xlabel('Frame')
    
    if fname:
        plt.savefig(fname)

# %%
def display_vctk_sample(vctk_speaker_id, sample_id, fname=None):
    # raw .wav file
    wav_file = os.path.join(vctk_folder, 'wav48/p' + str(vctk_speaker_id) + '/p' + str(vctk_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.wav')

    # print speaker info
    display(speaker_info[speaker_info['id']==vctk_speaker_id])

    # print text
    txt_file = wav_file.replace("wav48", "txt").replace(".wav", ".txt")
    f = open(txt_file, 'r')
    print(f.read())
    f.close()

    # play sample
    rate, wav_data = wavfile.read(wav_file)    
    display(IPython.display.Audio(data=wav_data, rate=rate, autoplay=True))
    
    if fname: 
        copyfile(wav_file, os.path.join(save_folder, os.path.basename(wav_file)))

    # plot waveform
    plt.figure(figsize=(15,4))
    plt.plot(wav_data)
    plt.grid(True)
    plt.xlim(0, len(wav_data))
    plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    if fname:
        plt.savefig(fname)
        
    # plot spectrogram
    plot_spectrogram(wav_data, rate)
    plt.savefig(fname + '_spectro')
    
        

def plot_spectrogram(wav_data, rate, title="Original Spectrogram"):
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    data = sp.butter_bandpass_filter(wav_data, lowcut, highcut, rate, order=1)
    #data = butter_bandpass_filter(data, 500, 7500, rate, order=1)
    # Only use a short clip for our demo
    if np.shape(data)[0]/float(rate) > 10:
        data = data[0:rate*10] 
    #print('Length in time (s):' + str(np.shape(data)[0]/float(rate)))

    wav_spectrogram = sp.pretty_spectrogram(wav_data.astype('float64'), fft_size = fft_size, 
                                       step_size = step_size, log = True, thresh = spec_thresh)

    fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,4))
    cax = ax.matshow(np.transpose(wav_spectrogram), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    fig.colorbar(cax)
    plt.title(title)
    #plt.xlim(0, len(wav_data))
    #plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))

# %%
 def plot_spectrogram_comparison(wav_file_a, wav_file_b, label_a='base', label_b='test',
                                 title="Original Spectrogram", b_mel=False):
        
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    #loop_dict['output_orig_fname']
    #loop_dict['output_fname']
    
    # load wav file data
    mywav_a = wav_file_a + '.wav'
    mywav_b = wav_file_b + '.wav'
    
    rate_a, data_a = wavfile.read(mywav_a)
    data_a = sp.butter_bandpass_filter(data_a, lowcut, highcut, rate_a, order=1)
    
    rate_b, data_b = wavfile.read(mywav_b)
    data_b = sp.butter_bandpass_filter(data_b, lowcut, highcut, rate_b, order=1)
    
    assert rate_a==rate_b, "Sampling rates don't match"
    
    # pad
    max_len = np.max([len(data_a), len(data_b)])
    
    tmp_a = data_a
    data_a = np.zeros(max_len)
    data_a[:len(tmp_a)] = tmp_a
    
    tmp_b = data_b
    data_b = np.zeros(max_len)
    data_b[:len(tmp_b)] = tmp_b
   

    # create spectrograms
    wav_spectrogram_a = sp.pretty_spectrogram(data_a.astype('float64'), fft_size = fft_size, 
                                           step_size = step_size, log = True, thresh = spec_thresh)

    wav_spectrogram_b = sp.pretty_spectrogram(data_b.astype('float64'), fft_size = fft_size, 
                                           step_size = step_size, log = True, thresh = spec_thresh)
    
    # create mel spectrograms if necessary
    if b_mel:        
         # Generate the mel filters
        mel_filter, mel_inversion_filter = sp.create_mel_filter(fft_size = fft_size,
                                                            n_freq_components = n_mel_freq_components,
                                                            start_freq = start_freq,
                                                            end_freq = end_freq, samplerate=rate_a) # may need to change sample rate
    
        # create mel spectrograms
        mel_spec_a = sp.make_mel(wav_spectrogram_a, mel_filter, shorten_factor = shorten_factor)
        mel_spec_b = sp.make_mel(wav_spectrogram_b, mel_filter, shorten_factor = shorten_factor)
        
        # use mel spectrograms in the plots (hacky, needs tidying up)
        wav_spectrogram_a = np.float64(mel_spec_a)
        wav_spectrogram_b = np.float64(mel_spec_b)

   
    # plot spectrograms and the differences
    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_a), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Spectrogram: ' + wav_file_a + '(' + label_a + ')')

    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_b), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Spectrogram: ' + wav_file_b + '(' + label_b + ')')

    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_b - wav_spectrogram_a), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Difference: (' + wav_file_b + ' - ' + wav_file_a + ') (' + label_b + ' - ' + label_a + ')')

# %%
def load_pre_calc_features(speaker_id, sample_id):
    pre_calc_features_folder = '/home/ubuntu/loop/data/vctk/numpy_features/'
    pre_calc_features_file = os.path.join(pre_calc_features_folder, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
    feats = np.load(pre_calc_features_file)
    
    return feats

def play_synthesized_features(feats):
    output_dir = './'
    output_file = 'test.wav'
    norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
    generate_merlin_wav(feats['audio_features'],
                        output_dir,
                        output_file,
                        norm_path)

    IPython.display.display(IPython.display.Audio(output_file + '.wav', autoplay=True))
    
    rate, wav_data = wavfile.read(output_file + '.wav')  
    
    return rate, wav_data

# %%
def generate_sample_with_loop(npz='', text='', spkr_id=1, checkpoint='models/vctk/bestmodel.pth', output_dir = './',
                             npz_path = '/home/ubuntu/loop/data/vctk/numpy_features'):
    #npz = ''
    #text = 'Your tickets for the social issues'
    #text = 'see that girl watch that scene'
    #npz = '/home/ubuntu/loop/data/vctk/numpy_features/p294_011.npz'
    #spkr_id = 12
    #checkpoint = 'checkpoints/vctk/lastmodel.pth'
    #checkpoint = 'models/vctk/bestmodel.pth'
    
    out_dict = dict()
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    gpu = 0

    # load loop weights & params from checkpoint
    weights = torch.load(checkpoint,
                         map_location=lambda storage, loc: storage)
    opt = torch.load(os.path.dirname(checkpoint) + '/args.pth')
    train_args = opt[0]

    train_dataset = NpzFolder('/home/ubuntu/loop/data/vctk/numpy_features')
    char2code = train_dataset.dict
    spkr2code = train_dataset.speakers

    norm_path = train_args.data + '/norm_info/norm.dat'
    norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
    train_args.noise = 0
    
    valid_dataset_path = npz_path + '_valid'

    
    # prepare loop model
    model = Loop(train_args)
    model.load_state_dict(weights)
    if gpu >= 0:
        model.cuda()
    model.eval()

    # check speaker id is valid
    if spkr_id not in range(len(spkr2code)):
        print('ERROR: Unknown speaker id: %d.' % spkr_id)

    # get phone sequence
    txt, feat, spkr, output_fname = None, None, None, None
    if npz is not '':
        # use pre-calculated phonemes etc.
        txt, feat, pre_calc_feat = npy_loader_phonemes(os.path.join(npz_path, npz))

        txt = Variable(txt.unsqueeze(1), volatile=True)
        feat = Variable(feat.unsqueeze(1), volatile=True)
        spkr = Variable(torch.LongTensor([spkr_id]), volatile=True)

        output_file = os.path.basename(npz)[:-4] + '_' + str(spkr_id)
        
        out_dict['pre_calc_feat'] = pre_calc_feat
        
    elif text is not '':
        # use specified text string
        # extract phonemes from the text
        txt = text2phone(text, char2code)
        feat = torch.FloatTensor(txt.size(0)*20, 63)
        spkr = torch.LongTensor([spkr_id])

        txt = Variable(txt.unsqueeze(1), volatile=True)
        feat = Variable(feat.unsqueeze(1), volatile=True)
        spkr = Variable(spkr, volatile=True)

        output_file = text.replace(' ', '_')
    else:
        print('ERROR: Must supply npz file path or text as source.')
        raise Exception('Need source')

    # use gpu
    if gpu >= 0:
        txt = txt.cuda()
        feat = feat.cuda()
        spkr = spkr.cuda()

    # run loop model to generate output features 
    loop_feat, attn = model([txt, spkr], feat)
    loop_feat, attn = trim_pred(loop_feat, attn)
    
    # add to output dictionary
    out_dict['txt'] = txt[:,0].squeeze().data.tolist()
    out_dict['spkr'] = spkr
    out_dict['feat'] = feat.data.cpu().numpy()
    out_dict['loop_feat'] = loop_feat.data.cpu().numpy()
    out_dict['attn'] = attn.squeeze().data.cpu().numpy()
    out_dict['output_file'] = output_file
    out_dict['valid_dataset_path'] = valid_dataset_path
    


    # generate .wav file from loop output features
    generate_merlin_wav(loop_feat.data.cpu().numpy(),
                        output_dir,
                        output_file,
                        norm_path)
    
    
    # generate .wav file from original features for reference
    if npz is not '':
        output_orig_fname = os.path.basename(npz)[:-4] + '.orig'
        generate_merlin_wav(feat[:, 0, :].data.cpu().numpy(),
                            output_dir,
                            output_orig_fname,
                            norm_path)
        out_dict['output_orig_fname'] = output_orig_fname
    
    return out_dict

# %%
def plot_attn(data, labels, dict_file):
    labels_dict = dict_file
    labels_dict = {v: k for k, v in labels_dict.iteritems()}
    labels = [labels_dict[x].decode('latin-1') for x in labels]

    plt.figure(figsize=(10,10))
    axarr = plt.subplot()
    axarr.imshow(data.T, aspect='auto', origin='lower', interpolation='nearest', cmap=cm.viridis)
    axarr.set_yticks(np.arange(0, len(data.T)))
    axarr.set_yticklabels(labels, rotation=90)

# %%
def text2phone(text, char2code):
    seperator = phonemizer.separator.Separator('', '', ' ')
    ph = phonemizer.phonemize(text, separator=seperator)
    ph = ph.split(' ')
    ph.remove('')

    ph = [p.replace('zh', 'jh') for p in ph]

    result = [char2code[p] for p in ph]
    return torch.LongTensor(result)

def trim_pred(out, attn):
    tq = attn.abs().sum(1).data

    for stopi in range(1, tq.size(0)):
        col_sum = attn[:stopi, :].abs().sum(0).data.squeeze()

        if type(tq[stopi]) == float:
            if tq[stopi] < 0.5 and col_sum[-1] > 4:
                break
        else:  
            if tq[stopi][0] < 0.5 and col_sum[-1] > 4:
                break

    out = out[:stopi, :]
    attn = attn[:stopi, :]

    return out, attn

def npy_loader_phonemes(path):
    feat = np.load(path)

    txt = feat['phonemes'].astype('int64')
    txt = torch.from_numpy(txt)

    audio = feat['audio_features']
    audio = torch.from_numpy(audio)

    return txt, audio, feat

# %% [markdown]
# # CSML MSc Project
# ## Speaker-Adaptive Neural Text-to-Speech Synthesis
#
# ### with Papercup

# %% [markdown]
# ### Agenda:
# * Summary of progress so far
# * Proposed research agenda
# * Feedback!
# * Agree next steps & milestones

# %%
Image("/home/ubuntu/loop/logo.png", width=100, height=100)

# %% [markdown]
# # I) Progress So Far

# %% [markdown]
# * **Started with Papercup last week**
#     - Plan is to be based with them throughout the summer

# %% [markdown]
# * **Set up tech/workflow tools**
#     - AWS, notebooks, PyCharm

# %% [markdown]
# * **Literature review**
#     * Using Mendeley

# %% [markdown]
# * **Benchmark implementation up & running**
#     - Data source, code, sensible results

# %% [markdown]
# * **Proposed research agenda**

# %% [markdown]
# #### My notes
# * Good initial progress
# * Built some momentum
# * Need guidance on research agenda
# * What makes a sensible/good project
# * What is expected in terms of write up
# <hr>

# %% [markdown]
# # II) Literature Review

# %% [markdown]
#  * **1) Domain background**
#     - Computational linguistics, phonemes, signal processing (spectrograms, MFCCs)

# %% [markdown]
# * **2) Traditional approaches to TTS**
#     - concatenative vs. statistical parametric

# %% [markdown]
# * **3) Sequence to sequence approaches to TTS**
#     - Tacotron (WaveNet), DeepVoice, VoiceLoop...
#     - Single speaker vs. multi-speaker (speaker embeddings spaces)

# %% [markdown]
# * ** 4) Wider literature on representation learning**
#     - VAE: conditional VAE, VQVAE, BetaVAE
#     - GAN: icGAN, infoGAN

# %% [markdown]
#     - Differ in how 'end-to-end' they are (text features, audio features, vocoder)
#
#     - Fader networks
#     - Style transfer
#
#     - Supervised vs. unsupervised

# %% [markdown]
# #### Notes
# * Could do various projects in this context...
# * Extend framework to new dataset (or new language)
# * Or in-the-wild dataset
# * Modifications to existing frames (e.g. loss functions)
# * My project:

# %% [markdown]
# # III) Proposed Research Agenda
# * Start with a benchmark model: **<font color=red>VoiceLoop multi-speaker using VCTK</font>**
#     - Released VoiceLoop uses 22 speakers: need to build sim on a larger subset of VCTK

# %% [markdown]
# * Investigate speaker embeddings in the benchmark
#     - PCA/T-SNE; Interpolation; Learning an embedding for an unseen speaker

# %% [markdown]
# * Supervised extension to speaker embeddings: **<font color=red>Fader Networks</font>**
#     - Trained to disentangle latent representation of input from labelled attributes
#     - Adversarial network that tries to identify labels of an example given the latent representation

# %% [markdown]
# * Unsupervised extentsion to speaker embeddings: **<font color=red>BetaVAE</font>**
#     - Hyperparameter that trades off reconstruction accuracy vs. distentangled latent factors
#     - Does it learn the factors from the supervised case (gender, accent) but without using labels?
#     - Does it learn additional factors e.g. depth of voice?

# %% [markdown]
# * Use techniques from 4) to learn and control speaker characterstics
#    - Use labels supplied in the VCTK dataset
#
#       - Add term to loss function to force speaker embedding layer to learn a representation from which adversarial network can't recover the labelsEncoder-decoder

# %% [markdown]
# # IV) Benchmark VoiceLoop Implementation
# * Facebook AI Research published the original VoiceLoop paper in July 2017
# * Sequence to sequence model with attention
#     - Inputs: `(phonemes, speaker_id)`
#     - Targets: `WORLD features`
#     - Encoder: lookup up tables for phonemes and speakers
#     - Attention: Gaussian mixture model
#     - Decoder: FIFO memory buffer
# * VCTK dataset

# %% [markdown]
# ## VCTK Dataset
# * Multispeaker English voice dataset
# * ~400 sentences per speaker
# * Each example consists of `(wav_file, text_transcript, speaker_id)`
# * University of Edinburgh's Cente for Speech Technology Research

# %%
speaker_info = get_vtck_speaker_info()

# %%
print "Number of Speakers: " + str(len(speaker_info))
display(speaker_info.iloc[10:25])
# Out:
# Number of Speakers: 108
#       id  age gender        accents            region
# 236  236   23      F        English        Manchester
# 237  237   22      M       Scottish              Fife
# 238  238   22      F  NorthernIrish           Belfast
# 239  239   22      F        English        SW England
# 240  240   21      F        English  Southern England
# 241  241   21      M       Scottish             Perth
# 243  243   22      M        English            London
# 244  244   22      F        English        Manchester
# 245  245   25      M          Irish            Dublin
# 246  246   22      M       Scottish           Selkirk
# 247  247   22      M       Scottish            Argyll
# 248  248   23      F         Indian
# 249  249   22      F       Scottish          Aberdeen
# 250  250   22      F        English        SE England
# 251  251   26      M         Indian

# %%
# plot descriptive statistics of speakers
plt.figure(figsize=(15,10))

for i, c in enumerate(['age', 'gender', 'accents']):
    plt.subplot(2,2,i+1)
    speaker_info[c].value_counts().sort_index().plot(kind='barh', color='red', grid=True, title=c)
    plt.xlabel('count')
    plt.ylabel(c)
    
plt.savefig(os.path.join(save_folder, 'vctk_descriptive_age_etc'))

# %%
display(speaker_info.iloc[10:25])

# set speaker here
speaker_id = 301
# Out:
#       id  age gender        accents            region
# 236  236   23      F        English        Manchester
# 237  237   22      M       Scottish              Fife
# 238  238   22      F  NorthernIrish           Belfast
# 239  239   22      F        English        SW England
# 240  240   21      F        English  Southern England
# 241  241   21      M       Scottish             Perth
# 243  243   22      M        English            London
# 244  244   22      F        English        Manchester
# 245  245   25      M          Irish            Dublin
# 246  246   22      M       Scottish           Selkirk
# 247  247   22      M       Scottish            Argyll
# 248  248   23      F         Indian
# 249  249   22      F       Scottish          Aberdeen
# 250  250   22      F        English        SE England
# 251  251   26      M         Indian

# %%
speaker_info.to_csv(os.path.join(save_folder, 'vctk_meta_data'), index=False)

# %%
# export all transcripts to .csv
x = []
for speaker_id in speaker_info.id:
    txt_folder = os.path.join(vctk_folder, 'txt/p' + str(speaker_id))
    txt_files = sorted(gl.glob(os.path.join(txt_folder, '*.txt')))

    s = []
    d = dict()
    
    for t in txt_files:
        f = open(t, 'r')
        txt = f.read()
        s.append(os.path.basename(t).replace('.txt', '') + ': ' + txt)
        #s.append(f.read())
        #print f.read()
        this_spkr = os.path.basename(t)[:-4].split('_')[0]
        this_sentence = os.path.basename(t)[:-4].split('_')[1]
        #d[os.path.basename(t).replace('.txt', '')] = txt
        x.append((this_spkr, this_sentence, txt.replace('\n', '')))
        f.close()
        
    # export all transcripts to .csv
    tmp = pd.DataFrame([d]).T
    tmp.columns = {'Transcript'}
    #tmp.to_csv(os.path.join(save_folder, 'transcript_' + str(speaker_id)))
    
    print "Done for: " + str(speaker_id)
# Out:
# Done for: 225
# Done for: 226
# Done for: 227
# Done for: 228
# Done for: 229
# Done for: 230
# Done for: 231
# Done for: 232
# Done for: 233
# Done for: 234
# Done for: 236
# Done for: 237
# Done for: 238
# Done for: 239
# Done for: 240
# Done for: 241
# Done for: 243
# Done for: 244
# Done for: 245
# Done for: 246
# Done for: 247
# Done for: 248
# Done for: 249
# Done for: 250
# Done for: 251
# Done for: 252
# Done for: 253
# Done for: 254
# Done for: 255
# Done for: 256
# Done for: 257
# Done for: 258
# Done for: 259
# Done for: 260
# Done for: 261
# Done for: 262
# Done for: 263
# Done for: 264
# Done for: 265
# Done for: 266
# Done for: 267
# Done for: 268
# Done for: 269
# Done for: 270
# Done for: 271
# Done for: 272
# Done for: 273
# Done for: 274
# Done for: 275
# Done for: 276
# Done for: 277
# Done for: 278
# Done for: 279
# Done for: 281
# Done for: 282
# Done for: 283
# Done for: 284
# Done for: 285
# Done for: 286
# Done for: 287
# Done for: 288
# Done for: 292
# Done for: 293
# Done for: 294
# Done for: 295
# Done for: 297
# Done for: 298
# Done for: 299
# Done for: 300
# Done for: 301
# Done for: 302
# Done for: 303
# Done for: 304
# Done for: 305
# Done for: 306
# Done for: 307
# Done for: 308
# Done for: 310
# Done for: 311
# Done for: 312
# Done for: 313
# Done for: 314
# Done for: 315
# Done for: 316
# Done for: 317
# Done for: 318
# Done for: 323
# Done for: 326
# Done for: 329
# Done for: 330
# Done for: 333
# Done for: 334
# Done for: 335
# Done for: 336
# Done for: 339
# Done for: 340
# Done for: 341
# Done for: 343
# Done for: 345
# Done for: 347
# Done for: 351
# Done for: 360
# Done for: 361
# Done for: 362
# Done for: 363
# Done for: 364
# Done for: 374
# Done for: 376

# %%
pd.DataFrame(x, columns=('Speaker', 'Sentence', 'Transcript')).to_csv(os.path.join(save_folder, 'vctk_transcripts'))

# %%
display(speaker_info)

# set speaker here
speaker_id = 301
# Out:
#       id  age gender        accents            region
# 225  225   23      F        English  Southern England
# 226  226   22      M        English            Surrey
# 227  227   38      M        English           Cumbria
# 228  228   22      F        English  Southern England
# 229  229   23      F        English  Southern England
# 230  230   22      F        English  Stockton-on-tees
# 231  231   23      F        English  Southern England
# 232  232   23      M        English  Southern England
# 233  233   23      F        English     Staffordshire
# 234  234   22      F       Scottish     West Dumfries
# 236  236   23      F        English        Manchester
# 237  237   22      M       Scottish              Fife
# 238  238   22      F  NorthernIrish           Belfast
# 239  239   22      F        English        SW England
# 240  240   21      F        English  Southern England
# 241  241   21      M       Scottish             Perth
# 243  243   22      M        English            London
# 244  244   22      F        English        Manchester
# 245  245   25      M          Irish            Dublin
# 246  246   22      M       Scottish           Selkirk
# 247  247   22      M       Scottish            Argyll
# 248  248   23      F         Indian
# 249  249   22      F       Scottish          Aberdeen
# 250  250   22      F        English        SE England
# 251  251   26      M         Indian
# 252  252   22      M       Scottish         Edinburgh
# 253  253   22      F          Welsh           Cardiff
# 254  254   21      M        English            Surrey
# 255  255   19      M       Scottish          Galloway
# 256  256   24      M        English        Birmingham
# ..   ...  ...    ...            ...               ...
# 311  311   21      M       American              Iowa
# 312  312   19      F       Canadian          Hamilton
# 313  313   24      F          Irish       County Down
# 314  314   26      F   SouthAfrican         Cape Town
# 315  315   18      M       American       New England
# 316  316   20      M       Canadian           Alberta
# 317  317   23      F       Canadian          Hamilton
# 318  318   32      F       American              Napa
# 323  323   19      F   SouthAfrican          Pretoria
# 326  326   26      M     Australian    English Sydney
# 329  329   23      F       American
# 330  330   26      F       American
# 333  333   19      F       American           Indiana
# 334  334   18      M       American           Chicago
# 335  335   25      F     NewZealand           English
# 336  336   18      F   SouthAfrican      Johannesburg
# 339  339   21      F       American      Pennsylvania
# 340  340   18      F          Irish            Dublin
# 341  341   26      F       American              Ohio
# 343  343   27      F       Canadian           Alberta
# 345  345   22      M       American           Florida
# 347  347   26      M   SouthAfrican      Johannesburg
# 351  351   21      F  NorthernIrish             Derry
# 360  360   19      M       American        New Jersey
# 361  361   19      F       American        New Jersey
# 362  362   29      F       American
# 363  363   22      M       Canadian           Toronto
# 364  364   23      M          Irish           Donegal
# 374  374   28      M     Australian           English
# 376  376   22      M         Indian
#
# [108 rows x 5 columns]

# %%
txt_folder = os.path.join(vctk_folder, 'txt/p' + str(speaker_id))
txt_files = sorted(gl.glob(os.path.join(txt_folder, '*.txt')))

s = []
d = dict()
for t in txt_files:
    f = open(t, 'r')
    txt = f.read()
    s.append(os.path.basename(t).replace('.txt', '') + ': ' + txt)
    #s.append(f.read())
    #print f.read()
    d[os.path.basename(t).replace('.txt', '')] = txt
    f.close()
    
#pd.DataFrame(s, [os.path.basename(t).replace('.txt', '') for t in txt_files])
display(s)


# set sample here
sample_id = 410
# Out:
# ['p301_001: Please call Stella.',
#  'p301_002: Ask her to bring these things with her from the store.',
#  'p301_003: Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob.',
#  'p301_004: We also need a small plastic snake and a big toy frog for the kids.',
#  'p301_005: She can scoop these things into three red bags, and we will go meet her Wednesday at the train station.',
#  'p301_006: When the sunlight strikes raindrops in the air, they act as a prism and form a rainbow.',
#  'p301_007: The rainbow is a division of white light into many beautiful colors.',
#  'p301_008: These take the shape of a long round arch, with its path high above, and its two ends apparently beyond the horizon.',
#  'p301_009: There is , according to legend, a boiling pot of gold at one end.',
#  'p301_010: People look, but no one ever finds it.',
#  'p301_011: When a man looks for something beyond his reach, his friends say he is looking for the pot of gold at the end of the rainbow.',
#  'p301_012: Throughout the centuries people have explained the rainbow in various ways.',
#  'p301_013: Some have accepted it as a miracle without physical explanation.',
#  'p301_014: To the Hebrews it was a token that there would be no more universal floods.',
#  'p301_015: The Greeks used to imagine that it was a sign from the gods to foretell war or heavy rain.',
#  'p301_016: The Norsemen considered the rainbow as a bridge over which the gods passed from earth to their home in the sky.',
#  'p301_017: Others have tried to explain the phenomenon physically.',
#  "p301_018: Aristotle thought that the rainbow was caused by reflection of the sun's rays by the rain.",
#  'p301_019: Since then physicists have found that it is not reflection, but refraction by the raindrops which causes the rainbows.',
#  'p301_020: Many complicated ideas about the rainbow have been formed.',
#  'p301_021: The difference in the rainbow depends considerably upon the size of the drops, and the width of the colored band increases as the size of the drops increases.',
#  'p301_022: The actual primary rainbow observed is said to be the effect of super-imposition of a number of bows.',
#  'p301_023: If the red of the second bow falls upon the green of the first, the result is to give a bow with an abnormally wide yellow band, since red and green light when mixed form yellow.',
#  'p301_024: This is a very common type of bow, one showing mainly red and yellow, with little or no green or blue.',
#  'p301_025: But it was a great decision he joked.',
#  'p301_026: They changed the world of music.',
#  'p301_027: You need a long-term strategy in football.',
#  'p301_028: The law has got to be upheld.',
#  "p301_029: But we're not the same person.",
#  'p301_030: He had just returned to Thailand from Canada.',
#  'p301_031: I saw the explosion and panicked.',
#  'p301_032: The punishment was swift.',
#  'p301_033: However, there are signs of dissent among his colleagues.',
#  'p301_034: I kept my side of the bargain.',
#  'p301_035: It also makes for interesting viewing.',
#  'p301_036: Jacques Chirac, the French president, was surely in his sights.',
#  'p301_037: He released a half-dozen solo albums.',
#  'p301_038: That respect is missing in the Netherlands.',
#  "p301_039: There's always a solution, somewhere you can meet in the middle.",
#  'p301_040: Hopefully they will just give me the degree.',
#  "p301_041: It doesn't make them evil.",
#  'p301_042: I have played really well all year.',
#  'p301_043: Parts of the system are already overstretched.',
#  'p301_044: Tourism in Scotland is facing a financial disaster.',
#  "p301_045: It's like, If he's all right, we will go with him.",
#  'p301_046: She added, It is the same story in both countries.',
#  'p301_047: Lara is very, very much a girl.',
#  'p301_048: I try not to expect anything.',
#  'p301_049: Lord Sainsbury is not a newcomer.',
#  'p301_050: There will be plenty to keep them occupied.',
#  'p301_051: It was, however, the wrong side.',
#  'p301_052: She is now planning a visit.',
#  'p301_053: It also calls for licensing of collection centres.',
#  'p301_054: Here he is, in effect, appointing himself a judge.',
#  'p301_055: Today, we begin to answer that question.',
#  "p301_056: No, it wasn't supposed to do that, officials admitted.",
#  'p301_057: I keep my fingers crossed.',
#  'p301_058: The encounter was to change his life.',
#  "p301_059: It's the best of both worlds.",
#  'p301_060: They have a way of proclaiming themselves.',
#  'p301_061: That is why we want this decision reversed.',
#  "p301_062: It didn't work against Sweden, but that was the intention.",
#  'p301_063: Staff were invited to make their own proposals.',
#  "p301_064: We tried everything, but it just wasn't to be today.",
#  'p301_065: After this, the exercise was due to begin.',
#  "p301_066: And she doesn't feel like Annika is better.",
#  'p301_067: I want my country to be a republic, not an empire.',
#  'p301_068: CELTIC Connections is here again - and the great debate.',
#  "p301_069: I'm just feeling very tired - but it's great.",
#  'p301_070: When he took over it really took off.',
#  "p301_071: That's just the way the game is evolving.",
#  'p301_072: Michael is putting on a brave face.',
#  'p301_073: Hopefully we can use this as a platform.',
#  'p301_074: The next thing will be cutting journey times.',
#  "p301_075: It's an excellent idea that makes sense.",
#  'p301_076: This is a mental challenge.',
#  'p301_077: Their one weakness was running between the wickets.',
#  'p301_078: He accused the Prime Minister of dithering.',
#  'p301_079: Without approval, the sport will find it difficult to develop.',
#  'p301_080: Ferguson did not hesitate.',
#  'p301_081: He came in an army uniform.',
#  'p301_082: However, within those figures, income from overseas visitors increased.',
#  'p301_083: Cars are great for going long distances.',
#  'p301_084: It was published yesterday on the internet.',
#  'p301_085: I knew he would play two weeks ago.',
#  'p301_086: The general secretary, represents a new era in Labour party politics.',
#  'p301_087: It has never been worthwhile.',
#  'p301_088: So other options had to be explored.',
#  'p301_089: He is firm but inclusive and very fair.',
#  'p301_090: We will learn lessons from what has happened.',
#  'p301_091: People love to see this stuff.',
#  'p301_092: One film a year is, he says, his natural rhythm.',
#  'p301_093: Three other people were treated for minor injuries.',
#  'p301_094: His female companion was being treated for shock.',
#  'p301_095: I have no plans to change the oath.',
#  'p301_096: We did not even get a free kick.',
#  'p301_097: He was married with a young child.',
#  'p301_098: Of course, on Tuesday, United were beaten despite this.',
#  'p301_099: Anyone remaining after that will be targeted.',
#  'p301_100: They serve a multitude of purposes.',
#  'p301_101: But his attendance is not guaranteed.',
#  'p301_102: I am sure all schools would accept that.',
#  'p301_103: I am very sorry to be here.',
#  'p301_104: I needed a change, a new challenge.',
#  'p301_105: Is your life a little too easy?',
#  'p301_106: I think my game is suited to grass.',
#  'p301_107: The little boy was playing football at lunchtime.',
#  'p301_108: Industry leaders reacted angrily.',
#  'p301_109: Europe will bear the brunt of the cuts.',
#  'p301_110: People want to see me on the screen.',
#  "p301_111: The Labour Party's not downbeat, and neither is the Labour Government.",
#  'p301_112: And that is our first victory in Edinburgh.',
#  "p301_113: The conversion didn't go over either.",
#  'p301_114: He took away my childhood.',
#  'p301_115: They hoped to remain in the Edinburgh area.',
#  'p301_116: The motive for the shooting was not known.',
#  'p301_117: Since then, they have fallen by more than two thirds.',
#  'p301_118: Serb forces then opened fire in their direction.',
#  'p301_119: It is not great art.',
#  'p301_120: You do not change overnight.',
#  'p301_121: The way they play, it is hard to score against them.',
#  'p301_122: One, the Acute Services Trust, will run the general hospital services.',
#  'p301_123: Over time, with patience and precision, the terrorists will be pursued.',
#  'p301_124: We all like to see forgiveness and redemption.',
#  'p301_125: We aim to put them out of business.',
#  'p301_126: Tony Blair should get out more.',
#  "p301_127: We didn't enjoy the first game, but today they were excellent.",
#  'p301_128: He was just awesome.',
#  'p301_129: We now have to concentrate on the league.',
#  'p301_130: We need to move forward together.',
#  'p301_131: She died in hospital two hours later.',
#  'p301_132: She was making a living, but her career was going nowhere.',
#  'p301_133: Both were later released after a check-up.',
#  'p301_134: No-one, however, was complacent about the size of the task.',
#  'p301_135: How good is Lennox Lewis?',
#  'p301_136: I would ask the fans to be patient.',
#  'p301_137: The ethos of the school was outstanding.',
#  'p301_138: The son has autism and other problems.',
#  "p301_139: I'm very puzzled by it.",
#  'p301_140: Florida is the pivotal state in the nation.',
#  'p301_141: Volvo is grateful to its staff in Irvine.',
#  'p301_142: We are both very confused and extremely angry.',
#  'p301_143: All things are possible if you believe.',
#  'p301_144: This was not just incongruous.',
#  'p301_145: It is patently true.',
#  'p301_146: You hope he prevails.',
#  'p301_147: And a mightily impressive recording it is, too.',
#  'p301_148: The fellowship is much more than a commission, he said.',
#  'p301_149: What the Department of Transport will make clear.',
#  'p301_150: But it looks good for next year.',
#  "p301_151: I haven't just gone in, done a three-hour rehearsal, and gone.",
#  'p301_152: He is wanted by German police for questioning.',
#  'p301_153: He was forced to quit.',
#  'p301_154: It is good for their eyesight.',
#  'p301_155: I was loving that little girl.',
#  "p301_156: But you can't have it both ways.",
#  "p301_157: We don't just play golf in Scotland.",
#  "p301_158: That's why the young musicians have joined.",
#  'p301_159: The death toll included five children.',
#  'p301_160: Before the game we went for a pint.',
#  'p301_161: There is no credible official announcement.',
#  'p301_162: I understand the medical concerns.',
#  'p301_163: This is a United Kingdom.',
#  'p301_164: I thought it was a fantastic game.',
#  'p301_165: I am aware that somebody made a threat.',
#  'p301_166: However, who could have predicted this result?',
#  'p301_167: Shyness has rarely sold in boxing terms.',
#  'p301_168: As long as it is possible, we will keep going.',
#  'p301_169: They were behind the wheel.',
#  'p301_170: The pressure on the aid agencies is immense.',
#  'p301_171: The problem arises because he does so much.',
#  'p301_172: The answer is mayhem.',
#  'p301_173: Our young people are leaving.',
#  'p301_174: What, then, is the real thing?',
#  "p301_175: I can't believe anyone would agree with it.",
#  'p301_176: That will be the sweetness.',
#  'p301_177: But is it ethical to practice in humans?',
#  'p301_178: The big issue for us is the review.',
#  'p301_179: There was a fossil on screen.',
#  'p301_180: I always loved the lightning in the movies.',
#  'p301_181: This does not create any precedent.',
#  'p301_182: I see social work as a vocation, a commitment.',
#  'p301_183: It has removed a bit of guilt.',
#  "p301_184: I'm just asking them to improve their disciplines.",
#  'p301_185: You can say he gets a sizeable amount.',
#  'p301_186: The early evidence suggests he did not.',
#  'p301_187: Ferguson had a most productive afternoon.',
#  'p301_188: I hope you miss the cut.',
#  'p301_189: The role was perfect for Russell.',
#  'p301_190: Morale is very high, despite the growing risks.',
#  'p301_191: We are seeking funds from government departments.',
#  'p301_192: That, though, was again according to manager McCall.',
#  'p301_193: He scored one goal and was on fire.',
#  'p301_194: I hate to say it, but you can understand it.',
#  'p301_195: Harold is a rarity.',
#  'p301_196: Walk out the door and anything can happen.',
#  'p301_197: I want him to take on Gomez.',
#  'p301_198: Her condition last night was described as critical.',
#  'p301_199: Frankly, it was worth the booking.',
#  'p301_200: They tend to be easily influenced by others.',
#  'p301_201: Well, what do you know?',
#  'p301_202: There are some serious ethical issues involved.',
#  'p301_203: If true, it will be the first sign of dissent.',
#  'p301_204: Europe has lost its way under the socialists.',
#  'p301_205: He will emerge as a world leader.',
#  'p301_206: It opens the door to the Champions League.',
#  'p301_207: It will include the Black Watch, the Royal Highland regiment.',
#  'p301_208: We have no choice but to shut down.',
#  'p301_209: The prognosis is excellent.',
#  'p301_210: They always want to give a performance.',
#  'p301_211: But he just carried on anyway.',
#  'p301_212: Iain Duncan Smith is wrong.',
#  'p301_213: I would not want to be young again.',
#  "p301_214: Meanwhile, the search continues for Ferguson's replacement.",
#  'p301_215: The Yugoslav army will still be there.',
#  'p301_216: There are schoolboys in uniform.',
#  'p301_217: They were later discharged from hospital.',
#  'p301_218: These findings would be made public.',
#  'p301_219: What are you not good at?',
#  'p301_220: All the lads are totally focused on that.',
#  "p301_221: He added later, Normally, it's not a dangerous river.",
#  'p301_222: This makes no sense!',
#  'p301_223: I go home only once.',
#  'p301_224: It had a gigantic effect.',
#  'p301_225: I, like many others, will consider where we go from here.',
#  'p301_226: If not, a deal could take many months.',
#  'p301_227: The team this year is going places.',
#  'p301_228: More money for students would help - in an ideal world.',
#  'p301_229: It took more than two years.',
#  'p301_230: Sullivan was later charged with her murder, which she denied.',
#  'p301_231: He said because people had invited him.',
#  "p301_232: That's the key issue isn't it?",
#  'p301_233: Its workforce is to be made redundant.',
#  'p301_234: Hopefully, it will pay off for me.',
#  'p301_235: Correction, knowing him, he might.',
#  'p301_236: I came up through the ranks.',
#  'p301_237: Why does she suddenly win everything now?',
#  'p301_238: We wanted it left for a wee while.',
#  'p301_239: These guys will not lie down.',
#  'p301_240: The Tories election campaign has certainly been colourful.',
#  'p301_241: That is nearly four people every day.',
#  'p301_242: There are nine people here now.',
#  'p301_243: His son is a local legend.',
#  'p301_244: Sir Jeremy, from Glasgow, said they had been delighted.',
#  'p301_245: Which perhaps is just as well.',
#  "p301_246: It wasn't a penalty, it was outside the area.",
#  'p301_247: He would just say it was terrible.',
#  'p301_248: This is the New Edinburgh.',
#  'p301_249: I saw military vehicles in the distance.',
#  'p301_250: I hope it has helped the prisoners.',
#  'p301_251: We kept going right to the final whistle.',
#  "p301_252: For sure, you won't know unless you ask him.",
#  'p301_253: JOHN Anderson, the former Scottish national coach, is still unearthing talent.',
#  'p301_254: The final stage is paranoia.',
#  'p301_255: I am not holding the club to ransom.',
#  'p301_256: Wagner was never like this.',
#  'p301_257: Pig farmers are completely despondent.',
#  'p301_258: But they cannot go on ignoring the truth.',
#  "p301_259: We would love for him to stay, but he's going home.",
#  "p301_260: That's the sort of game you want.",
#  "p301_261: We're not travel agents.",
#  'p301_262: Scotland has been caught in the crossfire.',
#  'p301_263: We are trying to clarify the issues.',
#  "p301_264: It's the same old story.",
#  'p301_265: He was telling me to keep quiet.',
#  'p301_266: It was a moment of madness.',
#  'p301_267: I do not own the vessel in question.',
#  'p301_268: Racism has no place in any sport.',
#  'p301_269: I am not happy with proposals for widows.',
#  'p301_270: It is believed she had serious head injuries.',
#  'p301_271: Bombing is the easy option.',
#  'p301_272: Drink and petrol prices remain untouched.',
#  "p301_273: We're not seeing an image of the person, he said.",
#  'p301_274: The pilot was making a visual approach.',
#  "p301_275: I'd say we should give it a week.",
#  'p301_276: Many other Scottish locations also feature.',
#  'p301_277: Little Voice is on general release.',
#  "p301_278: That doesn't make a whole lot of sense.",
#  'p301_279: There is no substitute.',
#  'p301_280: That nation is South Africa.',
#  'p301_281: This will secure the future of our industry.',
#  'p301_282: The police have an awful lot to explain.',
#  "p301_283: Wednesday's decision came as a surprise.",
#  "p301_284: That's when you hope to take advantage.",
#  'p301_285: It was an empowering journey.',
#  'p301_286: The board would report to the Scottish Parliament.',
#  "p301_287: It's not unlike the millennium bug.",
#  'p301_288: They had been together for about three years.',
#  'p301_289: Children are using books in a terrible condition.',
#  'p301_290: Everything has been destroyed.',
#  'p301_291: The painting was started, but finishing it was quite another matter.',
#  'p301_292: He is married, with one daughter, and lives in Kent.',
#  'p301_293: We just want to get stuck in now.',
#  'p301_294: Do you come from Moscow?',
#  'p301_295: Broomfield was the centre of the town.',
#  'p301_296: He or she will oversee the leadership contest.',
#  'p301_297: They are the innocent victims.',
#  'p301_298: We are aware of the tribunal case.',
#  'p301_299: That is the first job of the director - leadership.',
#  'p301_300: Her condition was yesterday described as critical, but stable.',
#  'p301_301: But he was a full, working member of our staff.',
#  'p301_302: Broke the birdie record.',
#  'p301_303: Either group is living in fantasy land.',
#  'p301_304: They tried to give her advice.',
#  'p301_305: That it is a brand name.',
#  "p301_306: We're talking about creating an attractive neighbourhood.",
#  'p301_307: Another casualty yesterday was John Prescott.',
#  'p301_308: They will have to make changes.',
#  'p301_309: This fact is supported by audience research.',
#  'p301_310: Of further privacy, he had no need.',
#  'p301_311: Both sides have to step back.',
#  'p301_312: Lord Johnston will give a decision later.',
#  'p301_313: They scored a goal, but we have to keep playing.',
#  'p301_314: It sounds a bit of an own goal.',
#  'p301_315: We are ready for the long haul.',
#  'p301_316: We lost our composure towards the interval, he said.',
#  'p301_317: I look for dancers who are also actors.',
#  'p301_318: However, civil rights campaigners welcomed the ruling.',
#  'p301_319: EMI is a prime example.',
#  "p301_320: I'm very pleased with what we have achieved.",
#  'p301_321: The observer saw no evidence of fighting.',
#  "p301_322: It's a record label, not a form of music.",
#  'p301_323: Not that Agassi was a believer.',
#  'p301_324: A friendship that will endure.',
#  'p301_325: Tourism is a vital industry for Scotland.',
#  'p301_326: It needs to be sorted out by Easter.',
#  'p301_327: Nowadays, it is workers united.',
#  'p301_328: He is young but not too young.',
#  'p301_329: I played well on Saturday and again today.',
#  'p301_330: It will also take evidence from consumers.',
#  'p301_331: He was my big brother, my father, my grandfather.',
#  'p301_332: I am not obsessed with sex.',
#  "p301_333: They've been at it for five hours.",
#  'p301_334: There is no answer to it.',
#  'p301_335: There was no let-up for the minnows.',
#  'p301_336: Birthdays are wonderful and terrible things.',
#  'p301_337: His English counterpart agreed.',
#  'p301_338: It was frightening, intense, and primal theatre.',
#  "p301_339: He wasn't really doing anything, so he wanted out.",
#  'p301_340: Anyway, she is playing a lesbian.',
#  'p301_341: I am not putting myself down.',
#  "p301_342: He's a joy to follow.",
#  'p301_343: Bob Dylan is getting old.',
#  'p301_344: We were lucky to have survived.',
#  'p301_345: Maybe we expected too much from the fixture.',
#  'p301_346: At this level, you have all to perform well.',
#  'p301_347: I just want to change my life.',
#  'p301_348: He did not oppose the divorce.',
#  'p301_349: Connell was standing there, ordering her to get up.',
#  'p301_350: And Michael was just great.',
#  'p301_351: He knew it would cost him millions.',
#  'p301_352: Law abiding motorists have nothing to fear.',
#  'p301_353: Sadly, the revival could not be sustained.',
#  'p301_354: Clearly, she says, she would never resort to such devices.',
#  'p301_355: That only came out during a radio interview.',
#  'p301_356: We are now setting about finding them.',
#  'p301_357: They were the best team, but unlucky in the end.',
#  'p301_358: We must not go down that road.',
#  "p301_359: It won't happen overnight, but things will get better.",
#  'p301_360: I am not among its admirers.',
#  'p301_361: And that match was played in June.',
#  'p301_362: He will address the nation this evening.',
#  'p301_363: They have shown a great desire and attitude.',
#  "p301_364: I couldn't really work outside Edinburgh.",
#  'p301_365: Motherwell have no such good fortune.',
#  'p301_366: But he is revelling in the big stage.',
#  'p301_367: Stock markets will be watching closely.',
#  'p301_368: If they have City backing, what is the influence?',
#  'p301_369: Moving from Manchester to London was upheaval enough.',
#  'p301_370: Mr Straw was home secretary at the time.',
#  'p301_371: There is no magical figure, but there are criteria.',
#  'p301_372: His job was not advertised.',
#  "p301_373: And the reason isn't too hard to fathom.",
#  'p301_374: Scottish life can be like this, too.',
#  'p301_375: He has changed my life for ever.',
#  'p301_376: The home was now under new management.',
#  'p301_377: It is like a theatre of the absurd.',
#  'p301_378: There is no openness.',
#  "p301_379: It's being very carefully looked at.",
#  'p301_380: It was a job he loved.',
#  'p301_381: It may encourage more people to prospect.',
#  'p301_382: Filtering through this material a composite finally emerges.',
#  'p301_383: Where was their passion, the power, the feeling?',
#  'p301_384: It looks like paradise.',
#  'p301_385: At the moment, it is being treated as a tragic accident.',
#  'p301_386: We were short of athletes.',
#  'p301_387: They want to avoid a flashpoint.',
#  'p301_388: They included certain insurance policies, and his share of the house.',
#  'p301_389: The wealth of talent in Australia is awesome.',
#  'p301_390: Even though the show is seriously exacting, physically demanding.',
#  'p301_391: I had no qualms about it.',
#  'p301_392: Muslim leaders in Italy have denied the charge.',
#  'p301_393: McMaster had already seen the first part.',
#  "p301_394: It's about my time as a guitarist.",
#  'p301_395: We have been working closely with Holyrood.',
#  'p301_396: It was early morning.',
#  'p301_397: Partition is not an option.',
#  'p301_398: What other retailer would do this?',
#  'p301_399: This is usually done by the space shuttle.',
#  "p301_400: Anyway, even if they didn't it wouldn't have mattered.",
#  "p301_401: I won't go back to Holland.",
#  'p301_402: In his absence, the council adopted the change.',
#  'p301_403: There was no cohesion.',
#  'p301_404: He is very popular in the squad, in England, and abroad.',
#  'p301_405: Whether this return was too soon.',
#  'p301_406: Jackson may well be right.',
#  'p301_407: My thoughts are with their families.',
#  'p301_408: I saw some good things.',
#  'p301_409: Princess Margaret is being buried on that day.',
#  'p301_410: Hopefully, we can learn from our mistakes.',
#  'p301_411: Still, the experience was amazing, she says.']

# %%
display_vctk_sample(speaker_id, sample_id, os.path.join(save_folder, 'wavplot_' + str(speaker_id) + '_' + str(sample_id)))
# Out:
#       id  age gender   accents          region
# 301  301   23      F  American  North Carolina
# Hopefully, we can learn from our mistakes.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# VoiceLoop only uses the speakers with American accents
speaker_info[speaker_info.accents == 'NewZealand']
# Out:
#       id  age gender     accents   region
# 335  335   25      F  NewZealand  English

# %% [markdown]
# - quick descriptive stats
# - show example of labels, say we can use these
# - show some examples

# %% [markdown]
# ## WORLD Features
# * WORLD is an open-source speech synthesis system that:
#     - 1) Can **analyse** speech data into WORLD features
#     - 2) Can **synthesise** WORLD features into synthesized speech

# %%
#speaker_id = 301
#sample_id = 117
# load pre-calculated WORLD features
feats = load_pre_calc_features(speaker_id, sample_id)

# %%
plot_lf0_etc(feats, os.path.join(save_folder, 'world_feats_' + str(speaker_id) + '_' + str(sample_id)))

# %% [markdown]
# #### Original VCTK Sample

# %%
speaker_id = 339
sample_id = 117

play_vctk_sample(speaker_id, sample_id, os.path.join(save_folder, 'orig_' + str(speaker_id) + '_' + str(sample_id)))
# Out:
#       id  age gender   accents        region
# 339  339   21      F  American  Pennsylvania
# There are exciting days ahead.
# dh eh r aa r ih k s ay t ih ng d ey z ax hh eh d
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# convert random piece of text to phonemes
# (useful for write-up)
train_dataset = NpzFolder('/home/ubuntu/loop/data/vctk/numpy_features')
char2code = train_dataset.dict
spkr2code = train_dataset.speakers

txt = text2phone('We talk about Mr Michael Johnson, and he is awesome.', char2code)
#txt = text2phone('tuesday', char2code)
x = feats['phonemes']
#x[x==42] = 0 # for some reason, sometimes there is a phoneme with index=42, which doesn't appear in the dict.
print " ".join(feats['code2phone'][txt])
# Out:
# w iy t ao k ax b aw t m ih s t er m ay k ax l jh aa n s ax n ae n d hh iy ih z aa s ax m

# %% [markdown]
# #### Synthesized Voice Using WORLD Features

# %%
# load pre-calculated WORLD features
feats = load_pre_calc_features(speaker_id, sample_id)
    
# synthesize sample from features and listen to the resulting .wav file
rate_synth, wav_data_synth = play_synthesized_features(feats, os.path.join(save_folder, 'synth_' + str(speaker_id) + '_' + str(sample_id)))
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete /home/ubuntu/msc-project-master/msc-project-master/docs/master/synth_339_117.wav.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Benchmark VoiceLoop Results

# %%
speaker_list_vctk = [294, 297, 299, 300, 301, 305, 306, 308, 310, 311, 318, 329, 330, 333, 334, 339, 341, 345, 360, 361, 362]
speaker_lookup = dict([(x, y) for x, y in enumerate(speaker_list_vctk)])

# %%
def get_npz_file(loop_speaker_id, sample_id):
    # Lookup dict from VCTK speaker IDs to the IDs used inside VoiceLoop
    # should really pick this up from the checkpoints, but it's convenient to have it available before/without a checkpoint being defined
    speaker_list_vctk = [294, 297, 299, 300, 301, 305, 306, 308, 310, 311, 318, 329, 330, 333, 334, 339, 341, 345, 360, 361, 362]
    speaker_lookup = dict([(x, y) for x, y in enumerate(speaker_list_vctk)])

    # load VCTK speaker_info metadata
    speaker_info = get_vtck_speaker_info()
    #speaker_info[speaker_info.id.isin(speaker_lookup.values())]
    tmp = pd.DataFrame.from_dict(speaker_lookup, orient='index', columns=['id'])
    #pd.merge(speaker_info, tmp)

    vctk_source_speaker_id = int(speaker_lookup[loop_speaker_id])
    npz_file= 'p' + str(vctk_source_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz'

    # display/listen to the VCTK sample
    #print "Original VCTK .wav File"
    #play_vctk_sample(vctk_source_speaker_id, sample_id)
    
    return npz_file

# %%
def play_vctk_version_loop_id(loop_speaker_id, sample_id, fname=None):
    # Lookup dict from VCTK speaker IDs to the IDs used inside VoiceLoop
    # should really pick this up from the checkpoints, but it's convenient to have it available before/without a checkpoint being defined
    speaker_list_vctk = [294, 297, 299, 300, 301, 305, 306, 308, 310, 311, 318, 329, 330, 333, 334, 339, 341, 345, 360, 361, 362]
    speaker_lookup = dict([(x, y) for x, y in enumerate(speaker_list_vctk)])

    # load VCTK speaker_info metadata
    speaker_info = get_vtck_speaker_info()
    #speaker_info[speaker_info.id.isin(speaker_lookup.values())]
    tmp = pd.DataFrame.from_dict(speaker_lookup, orient='index', columns=['id'])
    #pd.merge(speaker_info, tmp)

    vctk_source_speaker_id = int(speaker_lookup[loop_speaker_id])
    npz_file= 'p' + str(vctk_source_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz'

    # display/listen to the VCTK sample
    print "Original VCTK .wav File"
    play_vctk_sample(vctk_source_speaker_id, sample_id, fname)       
        
    return npz_file

# %% [markdown]
# #### Generate samples from a model checkpoint...

# %%
# generate based on an existing VCTK sample
source_speaker_id = 12
sample_id = 230
text = ''

# speaker id to use for VoiceLoop generation
gen_speaker_id = 9

# model checkpoint
checkpoint = 'checkpoints/vctk-rs/bestmodel.pth'
checkpoint = 'checkpoints/vctk-recover/bestmodel.pth'
checkpoint = 'models/vctk/bestmodel.pth'

output_dir = 'docs/master/'
output_file = 'loop_' + str(source_speaker_id) + '_' + str(sample_id) + '.wav'
norm_path = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
speaker_info[speaker_info.id==[speaker_lookup[gen_speaker_id]]]

# generate the sample
npz_file =  get_npz_file(source_speaker_id, sample_id)
loop_dict = generate_sample_with_loop(spkr_id=gen_speaker_id, npz=npz_file, text=text, checkpoint=checkpoint, output_dir=output_dir)
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p330_230_9.wav.
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p330_230.orig.wav.

# %% [markdown]
# #### 1) Original VCTK sample

# %%
npz_file = play_vctk_version_loop_id(source_speaker_id, sample_id, os.path.join(save_folder, 'orig_'+str(source_speaker_id)+'_'+str(sample_id)))
# Out:
# Original VCTK .wav File
#       id  age gender   accents region
# 330  330   26      F  American
# We talk about Mr Michael Johnson, and he is awesome.
# hh ow p f ax l iy w iy k ae n l er n f r ah m aw er m ih s t ey k s
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 2) WORLD Features

# %%
# Play WORLD version
IPython.display.display(Audio(loop_dict['output_orig_fname'] + '.wav', autoplay=True))
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 3) VoiceLoop Version

# %%
# listen to sample synthesized from VoiceLoop features
Audio(loop_dict['output_file'] + '.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Attention

# %%
plot_attn(loop_dict['attn'], loop_dict['txt'], NpzFolder(loop_dict['valid_dataset_path']).dict)

# %% [markdown]
# # V) Next Steps
# * Feedback on the research agenda
# * Structure of project report
#     - Literature review: useful or just padding?
# * Next meeting: Fri 29-June (3 weeks)
# * Milestones?
