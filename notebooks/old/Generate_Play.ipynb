# %%
import sys
sys.path.append('..')
import os
import shutil

import numpy
# %matplotlib notebook

from data import *
from model import Loop
from utils import generate_merlin_wav

from torch.autograd import Variable
from IPython.display import Audio

# %%
os.chdir('../')

# %%
os.getcwd()
# Out:
# '/home/ubuntu/loop'

# %%
#!python generate.py --npz data/vctk/numpy_features_valid/p318_212.npz --spkr 11 --checkpoint models/vctk/bestmodel.pth
# !python generate.py --npz data/vctk/numpy_features_valid/p318_212.npz --spkr 11 --checkpoint checkpoints/vctkPyCharm/bestmodel.pth
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p318_212.wav.
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p318_212.orig.wav.

# %%
Audio('p318_212.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('p318_212.orig.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python generate.py --text "She sells sea shells by the sea shore" --spkr 11 --checkpoint checkpoints/vctk/bestmodel.pth #models/vctk/bestmodel.pth
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete She_sells_sea_shells_by_the_sea_shore.wav.

# %%
Audio('test.wav.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('She_sells_sea_shells_by_the_sea_shore.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python generate.py --text "please help me" --spkr 13 --checkpoint models/vctk/bestmodel.pth
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete please_help_me.wav.

# %%
Audio('test.wav.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python generate.py --npz data/vctk/numpy_features_valid/p318_212.npz --spkr 11 --checkpoint checkpoints/vctk/bestmodel.pth
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p318_212.wav.
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p318_212.orig.wav.

# %%
Audio('test.wav.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('test.wav.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python generate.py --npz data/vctk/numpy_features_valid/p318_212.npz --spkr 11 --checkpoint models/vctk/bestmodel.pth
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete test.wav.wav.
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete p318_212.orig.wav.

# %%
Audio('test.wav.wav', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('test.wav.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('p318_212.orig.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
