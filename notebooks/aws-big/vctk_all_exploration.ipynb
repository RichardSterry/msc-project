# %% [markdown]
# # VCTK Exploration
# This notebook investigates the VCTK dataset.
# * Basic descriptive analysis (gender, age, accent, region)
# * Explore the text transcripts of the speaker utterances
# * Listen to original .wav samples
# * Listen to the synthesized .wav files created from the WORLD features
# * Visualize the pre-computed WORLD features for the samples

# %% [markdown]
# ## 1) Setup <a id='setup'></a>

# %%
# %matplotlib inline
import IPython.display
from ipywidgets import interact, interactive, fixed

import numpy as np
import matplotlib.pyplot as plt
import copy
from scipy.io import wavfile
#from scipy.signal import butter, lfilter
#import scipy.ndimage
import os
import argparse

#import spectrograms.spectrogram_utils as su

#import winsound
import pandas as pd

import glob as gl
from IPython.display import display, HTML

import pydub as pyd
import spectrogram as sp
from utils import generate_merlin_wav

from data import *

import shutil as sh

import evaluate_loss_func_for_notebook as el

# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/local/lib/python2.7/dist-packages/pydub/utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
vctk_raw_folder = '/home/ubuntu/VCTK-Corpus/'
vctk_prebuilt_folder = '/home/ubuntu/vctk-16khz-cmu-no-boundaries/'

# %%
def plot_spectrogram(wav_data, rate, title="Original Spectrogram"):
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    data = sp.butter_bandpass_filter(wav_data, lowcut, highcut, rate, order=1)
    #data = butter_bandpass_filter(data, 500, 7500, rate, order=1)
    # Only use a short clip for our demo
    if np.shape(data)[0]/float(rate) > 10:
        data = data[0:rate*10] 
    #print('Length in time (s):' + str(np.shape(data)[0]/float(rate)))

    wav_spectrogram = sp.pretty_spectrogram(wav_data.astype('float64'), fft_size = fft_size, 
                                       step_size = step_size, log = True, thresh = spec_thresh)

    fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,4))
    cax = ax.matshow(np.transpose(wav_spectrogram), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    fig.colorbar(cax)
    plt.title(title)
    #plt.xlim(0, len(wav_data))
    #plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))

# %%
 def plot_spectrogram_comparison(wav_file_a, wav_file_b, label_a='base', label_b='test',
                                 title="Original Spectrogram", b_mel=False):
        
    ### Parameters ###
    fft_size = 480# 2048 # window size for the FFT
    #step_size = int(fft_size/16) # distance to slide along the window (in time)
    step_size = 160 # distance to slide along the window (in time)
    spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
    lowcut = 500 # Hz # Low cut for our butter bandpass filter
    highcut = 7500 #15000 # Hz # High cut for our butter bandpass filter

    # For mels
    n_mel_freq_components = 40# 64 # number of mel frequency channels
    shorten_factor = 1#10 # how much should we compress the x-axis (time)
    start_freq = 300 # Hz # What frequency to start sampling our melS from 
    end_freq = 8000 # Hz # What frequency to stop sampling our melS from

    #loop_dict['output_orig_fname']
    #loop_dict['output_fname']
    
    # load wav file data
    mywav_a = wav_file_a + '.wav'
    mywav_b = wav_file_b + '.wav'
    
    rate_a, data_a = wavfile.read(mywav_a)
    data_a = sp.butter_bandpass_filter(data_a, lowcut, highcut, rate_a, order=1)
    
    rate_b, data_b = wavfile.read(mywav_b)
    data_b = sp.butter_bandpass_filter(data_b, lowcut, highcut, rate_b, order=1)
    
    assert rate_a==rate_b, "Sampling rates don't match"
    
    # pad
    max_len = np.max([len(data_a), len(data_b)])
    
    tmp_a = data_a
    data_a = np.zeros(max_len)
    data_a[:len(tmp_a)] = tmp_a
    
    tmp_b = data_b
    data_b = np.zeros(max_len)
    data_b[:len(tmp_b)] = tmp_b
   

    # create spectrograms
    wav_spectrogram_a = sp.pretty_spectrogram(data_a.astype('float64'), fft_size = fft_size, 
                                           step_size = step_size, log = True, thresh = spec_thresh)

    wav_spectrogram_b = sp.pretty_spectrogram(data_b.astype('float64'), fft_size = fft_size, 
                                           step_size = step_size, log = True, thresh = spec_thresh)
    
    # create mel spectrograms if necessary
    if b_mel:        
         # Generate the mel filters
        mel_filter, mel_inversion_filter = sp.create_mel_filter(fft_size = fft_size,
                                                            n_freq_components = n_mel_freq_components,
                                                            start_freq = start_freq,
                                                            end_freq = end_freq, samplerate=rate_a) # may need to change sample rate
    
        # create mel spectrograms
        mel_spec_a = sp.make_mel(wav_spectrogram_a, mel_filter, shorten_factor = shorten_factor)
        mel_spec_b = sp.make_mel(wav_spectrogram_b, mel_filter, shorten_factor = shorten_factor)
        
        # use mel spectrograms in the plots (hacky, needs tidying up)
        wav_spectrogram_a = np.float64(mel_spec_a)
        wav_spectrogram_b = np.float64(mel_spec_b)

   
    # plot spectrograms and the differences
    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_a), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Spectrogram: ' + wav_file_a + '(' + label_a + ')')

    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_b), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Spectrogram: ' + wav_file_b + '(' + label_b + ')')

    f, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,3))
    cax = ax.matshow(np.transpose(wav_spectrogram_b - wav_spectrogram_a), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
    f.colorbar(cax)
    plt.title('Difference: (' + wav_file_b + ' - ' + wav_file_a + ') (' + label_b + ' - ' + label_a + ')')

def plot_waveform_comparison(wav_file_a, wav_file_b, label_a='base', label_b='test',
                                 title="Original Spectrogram", b_mel=False):
        
    # load wav file data
    mywav_a = wav_file_a + '.wav'
    mywav_b = wav_file_b + '.wav'
    
    rate_a, data_a = wavfile.read(mywav_a)
    
    rate_b, data_b = wavfile.read(mywav_b)
    
    assert rate_a==rate_b, "Sampling rates don't match"
    
    # pad
    max_len = np.max([len(data_a), len(data_b)])
    
    tmp_a = data_a
    data_a = np.zeros(max_len)
    data_a[:len(tmp_a)] = tmp_a
    
    tmp_b = data_b
    data_b = np.zeros(max_len)
    data_b[:len(tmp_b)] = tmp_b
   

    max_a = data_a.max()
    min_a = data_a.min()
    max_b = data_b.max()
    min_b = data_b.min()
    
    max_both = max([max_a, max_b])
    min_both = min([min_a, min_b])
    
    plt.figure(figsize=(15,6))
    
    ax = plt.subplot(3, 1, 1)
    plt.plot(data_a)
    plt.grid(True)
    plt.xlim(0, len(data_a))
    plt.ylim(min_both, max_both)
    plt.gca().set_xticks(range(0,len(data_a), rate_a), range(0, np.int(np.ceil(1.0*len(data_a)/rate_a))))
    plt.title(label_a)
    plt.ylabel('Amplitude')
    
    ax = plt.subplot(3, 1, 2)
    plt.plot(data_b)
    plt.grid(True)
    plt.xlim(0, len(data_b))
    plt.ylim(min_both, max_both)
    ax.set_xticks(range(0,len(data_b), rate_b), range(0, np.int(np.ceil(1.0*len(data_b)/rate_b))))
    plt.title(label_b)
    plt.ylabel('Amplitude')
    
    ax = plt.subplot(3, 1, 3)
    plt.plot(data_b - data_a)
    plt.grid(True)
    plt.xlim(0, len(data_b))
    plt.ylim(min_both, max_both)
    ax.set_xticks(range(0,len(data_b), rate_b), range(0, np.int(np.ceil(1.0*len(data_b)/rate_b))))
    plt.title('Diff: ' + label_b + ' - ' + label_a)
    plt.ylabel('Amplitude')


def plot_mgc_feature_comparison(feats_a, feats_b, label_a, label_b):
    # plot mgc features
    plt.figure(figsize=(20,20))
    for x in range(60):
        plt.subplot(10, 6, x+1)
        plt.plot(feats_a[:, x])
        plt.plot(feats_b[:, x])
        plt.title('mgc' + str(x))
        if x == 5:
            plt.legend([label_a, label_b])
        if x < 6*9:
            plt.gca().get_xaxis().set_visible(False)
        if not np.mod(x, 6) == 0:
            plt.gca().get_yaxis().set_visible(False)

    plt.suptitle('mgc features', fontsize=14)
    plt.show()

def plot_other_feature_comparison(feats_a, feats_b, label_a, label_b):
    # plot lf0, vuv and bap features
    plt.figure(figsize=(20, 4))

    plt.subplot(1, 3, 1)
    plt.plot(feats_a[:, 60])
    plt.plot(feats_b[:, 60])
    plt.title('vuv')
    plt.grid(True)
    plt.legend([label_a, label_b])

    plt.subplot(1, 3, 2)
    plt.plot(feats_a[:, 61])
    plt.plot(feats_b[:, 61])
    plt.title('lf0')
    plt.grid(True)
    plt.legend([label_a, label_b])

    plt.subplot(1, 3, 3)
    plt.plot(feats_a[:, 62])
    plt.plot(feats_b[:, 62])
    plt.title('bap')
    plt.grid(True)
    plt.legend([label_a, label_b])

    plt.show()

# %%
def load_pre_calc_features(speaker_id, sample_id, b_valid=False, b_original=True):
    if b_original:
        pre_calc_features_folder = '/home/ubuntu/loop/data/vctk/numpy_features/'
    else:
        pre_calc_features_folder = '/home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/'
        
    if b_valid:
        pre_calc_features_folder = pre_calc_features_folder.replace('_features', '_features_numpy')
        
    pre_calc_features_file = os.path.join(pre_calc_features_folder, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
    feats = np.load(pre_calc_features_file)
    
    return feats

# %%
def play_synthesized_features(feats, norm_path='/home/ubuntu/loop/data/vctk/norm_info/norm.dat'):
    output_dir = './'
    output_file = 'test.wav'

    generate_merlin_wav(feats['audio_features'],
                        output_dir,
                        output_file,
                        norm_path)

    IPython.display.display(IPython.display.Audio(output_file + '.wav', autoplay=True))
    
    rate, wav_data = wavfile.read(output_file + '.wav')  
    
    return rate, wav_data

# %%
def display_vctk_sample(vctk_speaker_id, sample_id):
    # raw .wav file
    wav_file = os.path.join(vctk_raw_folder, 'wav48/p' + str(vctk_speaker_id) + '/p' + str(vctk_speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.wav')

    # print speaker info
    display(speaker_info[speaker_info['id']==vctk_speaker_id])

    # print text
    txt_file = wav_file.replace("wav48", "txt").replace(".wav", ".txt")
    f = open(txt_file, 'r')
    print(f.read())
    f.close()

    # play sample
    rate, wav_data = wavfile.read(wav_file)    
    display(IPython.display.Audio(data=wav_data, rate=rate, autoplay=True))

    # plot waveform
    plt.figure(figsize=(15,4))
    plt.plot(wav_data)
    plt.grid(True)
    plt.xlim(0, len(wav_data))
    plt.xticks(range(0,len(wav_data), 48000), range(0, np.int(np.ceil(1.0*len(wav_data)/48000))))

    # plot spectrogram
    plot_spectrogram(wav_data, rate)

# %%
def get_vtck_speaker_info():
    # this is the reference data file that comes as part of VCTK
    speaker_info_file = os.path.join(vctk_raw_folder, 'speaker-info.txt')

   # read file contents
    f = open(speaker_info_file, 'r')
    x = f.readlines()
    f.close()

    # extract column headers
    cols = x[0].lower().split()
    num_cols = len(cols)
    del x[0]
    num_speaker = len(x)

    # parse the data line by line
    d = dict()

    for idx in range(num_speaker):
        this_speaker_id = int(x[idx][:3])
        this_age = int(x[idx][5:7])
        this_gender = x[idx][9]
        residual = x[idx][14:].split()
        this_accent = residual[0]
        this_region = " ".join(residual[1:])

        # add speakers to a dictionary
        d[this_speaker_id] = (this_speaker_id, this_age, this_gender, this_accent, this_region)

    # convert to Pandas datafrae
    speaker_info = pd.DataFrame.from_dict(d, orient='index', columns=cols)
    
    return speaker_info

# %% [markdown]
# ## Questions...
# * Where are the norm files?

# %% [markdown]
# ## 2) Speaker Info <a id = 'speaker_info'></a>

# %%
# load VCTK speaker_info metadata
speaker_info = get_vtck_speaker_info()
#speaker_info[speaker_info.id.isin(speaker_lookup.values())]
#tmp = pd.DataFrame.from_dict(speaker_lookup, orient='index', columns=['id'])
#pd.merge(speaker_info, tmp)

# %%
speaker_info.head()
# Out:
#       id  age gender  accents            region
# 225  225   23      F  English  Southern England
# 226  226   22      M  English            Surrey
# 227  227   38      M  English           Cumbria
# 228  228   22      F  English  Southern England
# 229  229   23      F  English  Southern England

# %%
# plot descriptive statistics of speakers
for c in ['age', 'gender', 'accents']:
    plt.figure()
    speaker_info[c].value_counts().sort_index().plot(kind='barh', color='red', grid=True, title=c)
    plt.xlabel('count')
    plt.ylabel(c)

# %%
# there are lots of regions - too many to do much with them
pd.DataFrame(speaker_info.groupby(['accents', 'region']).count()['id'])
# Out:
#                               id
# accents       region
# American                       3
#               Alabama          1
#               California       2
#               Chicago          1
#               Florida          1
#               Indiana          1
#               Iowa             1
#               Napa             1
#               New England      1
#               New Jersey       2
#               New York         2
#               North Carolina   1
#               Ohio             1
#               Pennsylvania     1
#               Philadelphia     1
#               San Francisco    1
#               Tennessee        1
# Australian    English          1
#               English Sydney   1
# Canadian      Alberta          2
#               Hamilton         2
#               Montreal         1
#               Ontario          1
#               Toronto          2
# English       Birmingham       1
#               Cheshire         1
#               Cumbria          1
#               Essex            1
#               Leicester        1
#               London           1
# ...                           ..
#               Suffolk          1
#               Surrey           2
#               York             1
#               Yorkshire        2
# Indian                         3
# Irish         Athlone          1
#               Cork             1
#               County Down      1
#               Donegal          1
#               Dublin           4
#               Tipperary        1
# NewZealand    English          1
# NorthernIrish Belfast          5
#               Derry            1
# Scottish      Aberdeen         2
#               Argyll           1
#               Edinburgh        5
#               Fife             3
#               Galloway         1
#               Midlothian       1
#               Orkney           1
#               Perth            1
#               Ross             1
#               Selkirk          1
#               West Dumfries    1
#               West Lothian     1
# SouthAfrican  Cape Town        1
#               Johannesburg     2
#               Pretoria         1
# Welsh         Cardiff          1
#
# [70 rows x 1 columns]

# %% [markdown]
# ## 3) Playing the Raw Files
# * Start by identifying a speaker of interest
# * Then find an interesting sample
# * Then listen to the corresponding .wav file

# %% [markdown]
# #### Pick a speaker

# %%
# VoiceLoop only uses the speakers with American accents
speaker_info[speaker_info.accents == 'Irish']
# Out:
#       id  age gender accents       region
# 245  245   25      M   Irish       Dublin
# 266  266   22      F   Irish      Athlone
# 283  283   24      F   Irish         Cork
# 288  288   22      F   Irish       Dublin
# 295  295   23      F   Irish       Dublin
# 298  298   19      M   Irish    Tipperary
# 313  313   24      F   Irish  County Down
# 340  340   18      F   Irish       Dublin
# 364  364   23      M   Irish      Donegal

# %%
# set speaker here
speaker_id = 294

# %% [markdown]
# #### Pick a sample

# %%
txt_folder = os.path.join(vctk_raw_folder, 'txt/p' + str(speaker_id))
txt_files = sorted(gl.glob(os.path.join(txt_folder, '*.txt')))

s = []
for t in txt_files:
    f = open(t, 'r')
    s.append(os.path.basename(t).replace('.txt', '') + ': ' + f.read())
    #s.append(f.read())
    #print f.read()
    f.close()
    
#pd.DataFrame(s, [os.path.basename(t).replace('.txt', '') for t in txt_files])
display(s)
# Out:
# ['p294_001: Please call Stella.',
#  'p294_002: Ask her to bring these things with her from the store.',
#  'p294_003: Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob.',
#  'p294_004: We also need a small plastic snake and a big toy frog for the kids.',
#  'p294_005: She can scoop these things into three red bags, and we will go meet her Wednesday at the train station.',
#  'p294_006: When the sunlight strikes raindrops in the air, they act as a prism and form a rainbow.',
#  'p294_007: The rainbow is a division of white light into many beautiful colors.',
#  'p294_008: These take the shape of a long round arch, with its path high above, and its two ends apparently beyond the horizon.',
#  'p294_009: There is , according to legend, a boiling pot of gold at one end.',
#  'p294_010: People look, but no one ever finds it.',
#  'p294_011: When a man looks for something beyond his reach, his friends say he is looking for the pot of gold at the end of the rainbow.',
#  'p294_012: Throughout the centuries people have explained the rainbow in various ways.',
#  'p294_013: Some have accepted it as a miracle without physical explanation.',
#  'p294_014: To the Hebrews it was a token that there would be no more universal floods.',
#  'p294_015: The Greeks used to imagine that it was a sign from the gods to foretell war or heavy rain.',
#  'p294_016: The Norsemen considered the rainbow as a bridge over which the gods passed from earth to their home in the sky.',
#  'p294_017: Others have tried to explain the phenomenon physically.',
#  "p294_018: Aristotle thought that the rainbow was caused by reflection of the sun's rays by the rain.",
#  "p294_019: Since then physicists have found that it's not reflection, but refraction by the raindrops which causes the rainbows.",
#  'p294_020: Many complicated ideas about the rainbow have been formed.',
#  'p294_021: The difference in the rainbow depends considerably upon the size of the drops, and the width of the colored band increases as the size of the drops increases.',
#  'p294_022: The actual primary rainbow observed is said to be the effect of super-imposition of a number of bows.',
#  'p294_023: If the red of the second bow falls upon the green of the first, the result is to give a bow with an abnormally wide yellow band, since red and green light when mixed form yellow.',
#  'p294_024: This is a very common type of bow, one showing mainly red and yellow, with little or no green or blue.',
#  'p294_025: They were the better team on the night.',
#  'p294_026: The show is sold out, like the others in the run.',
#  'p294_027: It means we have to have some patience.',
#  'p294_028: For the moment, our position remains the same.',
#  'p294_029: I was pregnant and very worried.',
#  'p294_030: He said she was mad.',
#  'p294_031: They were impressive against France.',
#  "p294_032: I am delighted at Murray's appointment.",
#  'p294_033: The airport was even different.',
#  'p294_034: Other people had looked at it.',
#  'p294_035: A neighbour said the street was shocked.',
#  'p294_036: Michael, he is running!',
#  'p294_037: He was taken to hospital, but later died.',
#  'p294_038: Their ambition is to go back.',
#  'p294_039: He got the same story.',
#  'p294_040: My view has now changed completely.',
#  "p294_041: I've been dying for an hour.",
#  "p294_042: It wasn't a flight of fancy.",
#  "p294_043: We're playing away from home and that's it.",
#  "p294_044: I'm wondering what you feel about the youngest.",
#  'p294_045: They tend to be female and retired.',
#  'p294_046: Who was the mystery MP?',
#  'p294_047: This was no accident.',
#  "p294_048: I'm really looking forward to seeing the fight.",
#  "p294_049: We've all done it!",
#  'p294_050: In fact, it is deeply unpleasant.',
#  "p294_051: Hopefully, that'll come from someone on our side.",
#  'p294_052: The course record was in his name.',
#  'p294_053: But we welcome this document.',
#  'p294_054: What is the point of jailing him?',
#  'p294_055: We should not bring him into a dispute.',
#  'p294_056: This is a possible way forward.',
#  'p294_057: I am not here to get even.',
#  'p294_058: Freedom from Serbia is a growing objective.',
#  'p294_059: We are only human.',
#  'p294_060: I went with the mood.',
#  "p294_061: I think we'll just keep it.",
#  'p294_062: Debate is not just talk.',
#  'p294_063: How is he enjoying life as a senior?',
#  'p294_064: It is all about having physical evidence.',
#  'p294_065: People remember the Tories in office.',
#  'p294_066: What kind of inclusion is that?',
#  'p294_067: I fell in love with it right away.',
#  'p294_068: Domestic abuse is related to power and control.',
#  'p294_069: It makes for an interesting conference.',
#  "p294_070: I don't have any answer for them.",
#  'p294_071: It took about five or six hours.',
#  'p294_072: I found the course inspiring.',
#  'p294_073: Two things were clear from the new programme.',
#  'p294_074: This is the real thing now.',
#  'p294_075: Until they came to do it.',
#  'p294_076: She now lives in London.',
#  'p294_077: It will not be a long campaign.',
#  'p294_078: Subs not used, McGraw.',
#  'p294_079: Three bystanders were killed.',
#  'p294_080: One policeman was killed.',
#  'p294_081: They could not have done more for me.',
#  'p294_082: It was like a vacuum.',
#  'p294_083: That was enough for the committee.',
#  'p294_084: It is a very genuine prospect.',
#  'p294_085: It is the tip of the iceberg.',
#  'p294_086: We have to focus on what is important.',
#  'p294_087: They have to work so hard.',
#  "p294_088: It's not very pretty, but it's effective.",
#  'p294_089: Seven British members of the club are missing.',
#  'p294_090: He had just returned from a run.',
#  "p294_091: There's a strong involvement.",
#  'p294_092: Now, though, he has an incentive.',
#  "p294_093: But now it's back to golf.",
#  'p294_094: It should be a condition of employment.',
#  'p294_095: Was it a signal?',
#  'p294_096: It may not even be possible.',
#  'p294_097: In fact, they go hand in hand.',
#  'p294_098: I gave him a way out, and he took it.',
#  'p294_099: So is that it, then?',
#  'p294_100: You should have let it write the cards.',
#  "p294_101: It's annoying in a way.",
#  "p294_102: It's too close to call.",
#  "p294_103: It's a long process.",
#  'p294_104: I asked to take it up to Glasgow.',
#  'p294_105: Sacking John Redwood is a disaster.',
#  'p294_106: The other conditions were not specified.',
#  "p294_107: I've never felt affection for Emu.",
#  "p294_108: That's not part of the deal.",
#  'p294_109: That was the context of his remarks.',
#  'p294_110: This has gone on too long.',
#  'p294_111: We have great confidence in Derek.',
#  'p294_112: My ambition is to tell a good story.',
#  "p294_113: I don't know the nature of the illness.",
#  'p294_114: The industry will try to get round it.',
#  'p294_115: Who will deliver more service to Scotland?',
#  'p294_116: I want to make a vigorous defence.',
#  'p294_117: And she got it.',
#  'p294_118: We are the weakest link.',
#  'p294_119: We have now no choice.',
#  'p294_120: My father and mother are.',
#  "p294_121: We don't know what happened after.",
#  'p294_122: Did he just want to be on telly?',
#  'p294_123: He seems to be used to the attention.',
#  "p294_124: It's an hour of the same response.",
#  'p294_125: We have very real concerns about it.',
#  'p294_126: He has gone through the process before.',
#  'p294_127: People will see this over time.',
#  "p294_128: I can't speak for him.",
#  'p294_129: They were married in Edinburgh last summer.',
#  'p294_130: The lowest increase was recorded in Dundee.',
#  "p294_131: I can't see him reversing that.",
#  "p294_132: I'm deeply sorry they did.",
#  'p294_133: I can lead by example.',
#  'p294_134: I have had a wonderful career.',
#  'p294_135: It seemed to have direction.',
#  'p294_136: This takes the pressure off.',
#  'p294_137: It was different in the endurance events.',
#  'p294_138: Above all, the approach is upbeat.',
#  'p294_139: The objective was achieved.',
#  'p294_140: It was a hugely popular decision.',
#  'p294_141: He invented the language.',
#  'p294_142: Where are they?',
#  "p294_143: It's hard not to.",
#  'p294_144: It is a question of life and death.',
#  'p294_145: However, there are no plans for injecting rooms.',
#  'p294_146: You ask the question.',
#  'p294_147: She was always a quality act.',
#  'p294_148: We are all very proud of her.',
#  "p294_149: I'm sure that is not.",
#  "p294_150: It's a great idea.",
#  "p294_151: It's like a score in some ways.",
#  "p294_152: It's a wonderful piece of water.",
#  'p294_153: Feel the air, the space.',
#  'p294_154: Therein lies the problem.',
#  'p294_155: You feel the pride.',
#  'p294_156: We are well insured.',
#  'p294_157: I was quietly confident about getting the win.',
#  'p294_158: The Treasury denied the claims.',
#  "p294_159: You've been working for four years.",
#  'p294_160: I am the Son of Sam.',
#  'p294_161: There is no shortage of commitment.',
#  'p294_162: Such as it is.',
#  'p294_163: He deserves a second chance.',
#  'p294_164: He also admitted.',
#  'p294_165: There was no change in the strategy.',
#  "p294_166: There's been a mistake.",
#  'p294_167: It had until tomorrow to comply.',
#  'p294_168: Genetic assessment is crucial.',
#  'p294_169: I enjoy my work.',
#  'p294_170: We have managed to get it under control.',
#  'p294_171: We have a genuine budget in place.',
#  'p294_172: Art is still a risky investment.',
#  'p294_173: It was little else.',
#  'p294_174: These things can happen.',
#  'p294_175: Family members are at her bedside.',
#  'p294_176: You have to go to the edges.',
#  "p294_177: I'm looking forward to facing the Irishmen.",
#  'p294_178: Harry will be up for it.',
#  'p294_179: He could tell you.',
#  'p294_180: My place is in the kitchen.',
#  'p294_181: He was, indeed, a thoroughly decent man.',
#  'p294_182: A decision is expected in September.',
#  'p294_183: It was a big departure.',
#  "p294_184: That's the name of the game, though.",
#  "p294_185: It's a huge amount.",
#  'p294_186: The fire was falling from the sky.',
#  'p294_187: I want my mum.',
#  'p294_188: This is simply unjust.',
#  'p294_189: The First Minister is an addict.',
#  'p294_190: Its role is not to interfere.',
#  'p294_191: It is becoming a bit of a habit.',
#  "p294_192: You can't believe a word.",
#  'p294_193: Something happened on that island.',
#  "p294_194: You can't get a mortgage.",
#  'p294_195: It is misleading to compare the two.',
#  'p294_196: I want a career.',
#  'p294_197: He said nothing to waiting journalists.',
#  'p294_198: O Leary was clearly disgusted.',
#  "p294_199: That's been the case for a while.",
#  'p294_200: When it is ready, it will be signed.',
#  'p294_201: All options are on the table.',
#  'p294_202: It will determine whether an offence has occurred.',
#  'p294_203: We now have a moment of hope.',
#  'p294_204: They should not be blamed for it.',
#  'p294_205: Our traditions and cultures remain the same.',
#  'p294_206: The first eviction takes place on Sunday.',
#  'p294_207: It will take some time to establish.',
#  'p294_208: This club is perfect for me.',
#  "p294_209: And do you know, it just wasn't the same.",
#  'p294_210: This came as no great surprise to anyone.',
#  'p294_211: I love this job.',
#  'p294_212: I have no secrets.',
#  'p294_213: We are very, very pleased with the response.',
#  "p294_214: He doesn't need to be told, he knows the truth.",
#  'p294_215: They will form a tribute.',
#  "p294_216: We're very, very excited.",
#  "p294_217: It's not a question of talking.",
#  'p294_218: He was certainly upbeat about his chances.',
#  'p294_219: Then they killed another three.',
#  'p294_220: We are not a retailer, we provide a service.',
#  'p294_221: The six others were injured.',
#  'p294_222: She has so much to offer.',
#  'p294_223: They are not the answer to staff shortages.',
#  'p294_224: It should be a pretty exciting session.',
#  'p294_225: Gas is too expensive.',
#  'p294_226: Advice and counselling will be offered.',
#  'p294_227: Are we going mainstream?',
#  'p294_228: I could not believe what they were saying.',
#  'p294_229: The protest will go ahead as planned.',
#  'p294_230: Who will run the bigger show?',
#  "p294_231: General, You didn't get a modified.",
#  "p294_232: I'm not a little girl.",
#  'p294_233: We have seen the future, and it is different.',
#  'p294_234: Who does he think will win?',
#  "p294_235: We're talking about one or two years.",
#  'p294_236: I just have to accept that.',
#  'p294_237: He was overwhelmed by the response.',
#  'p294_238: They will do nothing for the local people.',
#  'p294_239: Do it for us now.',
#  'p294_240: We got the guarantee.',
#  "p294_241: I couldn't have asked for better.",
#  'p294_242: That is however, the only part of the story.',
#  'p294_243: But happily, the story is true.',
#  'p294_244: They are not suitable.',
#  'p294_245: Some days are different from others.',
#  'p294_247: Everything else is the same.',
#  'p294_248: They never gave up hope.',
#  'p294_249: But it was a pleasure.',
#  'p294_250: There are no excuses left for us.',
#  'p294_251: Mental health is a massive issue.',
#  'p294_252: His director of football is leaving.',
#  "p294_253: We don't want to be too intrusive.",
#  'p294_254: Their own instinctive response was confirmed.',
#  'p294_255: There are still some matters to be discussed.',
#  'p294_256: This would give Scotland around eight members.',
#  'p294_257: I get on him, he gets on me.',
#  'p294_258: They are in care for a reason.',
#  'p294_259: A Scotsman has to defend his castle.',
#  "p294_260: I haven't a clue.",
#  'p294_261: It has certainly not been an enjoyable experience.',
#  'p294_262: I thought he was terrific.',
#  'p294_263: A statement is expected in April.',
#  'p294_264: It possibly depends on the position.',
#  'p294_265: This will have no effect on the championship.',
#  "p294_266: We didn't turn it into the inspectors.",
#  'p294_267: I would love to travel with it.',
#  'p294_268: Detectives are waiting to interview the men.',
#  'p294_269: It is a common condition in children.',
#  'p294_270: We will work through the night.',
#  'p294_271: I also thought, This is a feature film.',
#  'p294_272: For now, they have gone as far as they can.',
#  'p294_273: Boy is the town a mess.',
#  "p294_274: It's as simple as that.",
#  "p294_275: We've been here before.",
#  'p294_276: Neither of them was badly hurt.',
#  'p294_277: From there, it was a success story.',
#  'p294_278: It is a very disturbing picture for men.',
#  'p294_279: I have come here to fight the boxer, not the fans.',
#  'p294_280: It was one in the afternoon.',
#  "p294_281: I've never seen them down here.",
#  'p294_282: For some, it might not make too much difference.',
#  'p294_283: This is our unfinished business.',
#  'p294_284: This is our chance in Northern Ireland.',
#  'p294_285: He had asked if they had the script.',
#  "p294_286: It didn't work against Sweden, but that was the intention.",
#  'p294_287: This could take a few days.',
#  'p294_288: A great deal was achieved.',
#  'p294_289: So it was sad.',
#  "p294_290: It's a blunt instrument anyway.",
#  'p294_291: There did not need to be a miracle.',
#  'p294_292: This could also affect the sentencing.',
#  'p294_293: That case has still not been settled.',
#  'p294_294: What do they do, anyway?',
#  "p294_295: They've got a mountain to climb.",
#  'p294_296: It just would not work.',
#  'p294_297: The acting left a lot to be desired.',
#  'p294_298: Who will provide the wine?',
#  'p294_299: We started from scratch.',
#  'p294_300: There was no happiness.',
#  'p294_301: Their bid was a very good one.',
#  'p294_302: Everything is so commercial.',
#  'p294_303: And this tournament will travel.',
#  'p294_304: Could it have been better spent?',
#  'p294_305: If that is the case, it is a breakthrough.',
#  'p294_306: The order went out.',
#  'p294_307: Cinema is a communal experience.',
#  'p294_308: The appeal is impartial.',
#  'p294_309: You could see he was thinking about it.',
#  'p294_310: He added, We are full of anger.',
#  'p294_311: They have nowhere else to go.',
#  'p294_312: However, it seems that he got it wrong.',
#  'p294_313: We work for the athlete.',
#  'p294_314: It is three years at present.',
#  'p294_315: The document is a starting point for discussion.',
#  'p294_316: We all make mistakes.',
#  "p294_317: It didn't put me off.",
#  'p294_318: Now they have found out the truth.',
#  'p294_319: It is an impressive record.',
#  'p294_320: Johnson was pretty low.',
#  'p294_321: We know we have done wrong.',
#  'p294_322: She was married with one son.',
#  'p294_323: I wanted to drop out.',
#  'p294_324: I told you so.',
#  "p294_325: He's a good player, but he's not the only one.",
#  'p294_326: Which is where the manager comes in.',
#  'p294_327: Is that what people we want?',
#  'p294_328: There are so many unanswered questions.',
#  'p294_329: Then it was into a series of classes.',
#  'p294_330: He wants to play in the Champions League.',
#  "p294_331: I'm so happy that she did.",
#  'p294_332: The need for further investment is obvious.',
#  'p294_333: Iraq has no interest in war.',
#  "p294_334: It's hard, but we have had so much to do.",
#  'p294_335: But it took a lot of bottle.',
#  'p294_336: Holiday was certainly no stranger to bigotry.',
#  'p294_337: That period was a struggle.',
#  'p294_338: No-one else was hurt.',
#  "p294_339: What's it for?",
#  'p294_340: Downing Street defended the scale of the awards.',
#  'p294_341: Anything can happen - at any moment.',
#  'p294_342: She is an imposing presence.',
#  'p294_343: There are moments of joy in politics.',
#  'p294_344: Is a drug dealer?',
#  'p294_345: Where are you taking her?',
#  'p294_346: Yesterday, he was busy in his office.',
#  "p294_347: It's just not our biggest problem.",
#  'p294_348: The result could be all down to turnout.',
#  "p294_349: I'm not going to change from it.",
#  'p294_350: There were no violations.',
#  'p294_351: That was the type of man he was.',
#  'p294_352: They are not falling now.',
#  'p294_353: They had to explain it.',
#  "p294_354: We didn't mean to kill him.",
#  'p294_355: The support of Britain is assumed.',
#  'p294_356: So far he has not done so.',
#  'p294_357: He completely loses control.',
#  'p294_358: No decision on that was taken.',
#  'p294_359: My fitness was very poor.',
#  'p294_360: The trial continues today.',
#  'p294_361: People come to see the Highlands.',
#  'p294_362: Europe is a bonus.',
#  'p294_363: It is also used to buy coffins.',
#  "p294_364: I've got to provide for my family.",
#  'p294_365: Such debate is pointless.',
#  'p294_366: And it had two seats.',
#  'p294_367: Cooking is intricate and complex.',
#  'p294_368: He found it very hard to understand.',
#  'p294_369: But it would change the context.',
#  'p294_370: But who was driving it?',
#  'p294_371: We recorded it at our own expense.',
#  'p294_372: But opponents were quick to criticise.',
#  'p294_373: Try to save us.',
#  'p294_374: We also have had to work the dark side, if you will.',
#  'p294_375: We need to increase the membership.',
#  'p294_376: Social workers are on stand-by to help.',
#  'p294_377: Certainly, there is much on the agenda.',
#  'p294_378: There could be a way back.',
#  'p294_379: He edited the press release.',
#  'p294_380: Visitors were also impressed.',
#  'p294_381: It was very, very difficult for me to look at this.',
#  'p294_382: Thankfully, Mr Campbell was able to help.',
#  'p294_383: Are there muscular problems?',
#  'p294_384: We had our chances.',
#  'p294_385: However, many questions remained unanswered.',
#  'p294_386: I told her, and she was extremely grateful.',
#  'p294_387: He is in the queue.',
#  'p294_388: But what is?',
#  "p294_389: It wasn't about her singing, though.",
#  'p294_390: We have other options.',
#  'p294_391: Calvin was back at his best today.',
#  'p294_392: My mind was made up.',
#  'p294_393: Nine days later, he suffered another attack.',
#  'p294_394: And rugby fans can help.',
#  "p294_395: The council's concern is very simple.",
#  'p294_396: We are on the path of change.',
#  "p294_397: Rangers didn't turn up, by the way.",
#  'p294_398: No other vehicle was involved in the accident.',
#  "p294_399: It's very simple, no-one is forced to compete.",
#  "p294_400: Of course, it doesn't all come off.",
#  'p294_401: In fact, he should never have been in the field.',
#  'p294_402: He promised a final decision within a fortnight.',
#  'p294_403: We will deal with the refugees.',
#  'p294_404: The pair are no strangers to smashing records.',
#  "p294_405: It's a tragedy for the area.",
#  'p294_406: It was very well received.',
#  "p294_407: I don't think there's going to be one.",
#  'p294_408: If you could find it.',
#  'p294_409: Such is the ego involved.',
#  'p294_410: Mr Wilson has received no such request.',
#  'p294_411: It raises the edge.',
#  'p294_412: It was not known to myself.',
#  'p294_413: It is a delight on every level.',
#  'p294_414: Would it really be good to shorten it?',
#  "p294_415: I don't entirely buy that.",
#  'p294_416: England could not take anything for granted, however.',
#  'p294_417: I saw it in a different way.',
#  "p294_418: Or, rather, it isn't.",
#  'p294_419: We have every respect for Michelle.',
#  'p294_420: Mr Blunkett was convinced.',
#  'p294_421: The auction will be held tomorrow.',
#  'p294_422: It was really enjoyable on Saturday.',
#  'p294_423: Athletics is on a roll in the country.',
#  'p294_424: He died at the hands of his captors.']

# %%
# set sample here
sample_id = 416

# %% [markdown]
# #### Play the audio file

# %%
display_vctk_sample(speaker_id, sample_id)
# Out:
#       id  age gender   accents         region
# 294  294   33      F  American  San Francisco
# England could not take anything for granted, however.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 4) Comparison of Original Samples to Synthesized Samples
# * Load the pre-calculated WORLD features for the speaker-sample you listened to in part 3
# * Note how the synthesized version compares to the original (some are very good, others less so)
# * Plots below show how the waveforms and spectrograms compare. Typically they're similar, but with clear differences.
# * The VCTK .wav files typically start with a long silence, which doesn't appear in the WORLD features. We should strip the silence out really to make the .wav files comparable.

# %% [markdown]
# #### Original pre-calculated features

# %%
# load pre-calculated WORLD features
feats = load_pre_calc_features(speaker_id, sample_id)

# synthesize sample from features and listen to the resulting .wav file
rate_synth, wav_data_synth = play_synthesized_features(feats)
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete test.wav.wav.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##### Jiameng's Features

# %%
# load pre-calculated WORLD features
feats_jiameng = load_pre_calc_features(speaker_id, sample_id, b_original=False)

# synthesize sample from features and listen to the resulting .wav file
rate_synth_jiameng, wav_data_synth_jiameng = play_synthesized_features(feats_jiameng, norm_path='/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/norm_info/norm.dat')
# Out:
# {'mgc': 0, 'vuv': 60, 'lf0': 61, 'bap': 62}
# complete test.wav.wav.
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Plot waveform

# %%
# plot waveform
plt.figure(figsize=(15,6))

# original .wav file
plt.subplot(2,1,1)
plt.plot(wav_data_synth)
plt.grid(True)
plt.xlim(0, len(wav_data_synth))
plt.xticks(range(0,len(wav_data_synth), rate_synth), range(0, np.int(np.ceil(1.0*len(wav_data_synth)/rate_synth))))
plt.title('Original Sample')

# synthesized .wav file
plt.subplot(2,1,2)
plt.plot(wav_data_synth_jiameng)
plt.grid(True)
plt.xlim(0, len(wav_data_synth_jiameng))
plt.xticks(range(0,len(wav_data_synth_jiameng), rate_synth), range(0, np.int(np.ceil(1.0*len(wav_data_synth_jiameng)/rate_synth))))
plt.title('Synthesized Sample')

plt.show()

# %% [markdown]
# #### Plot Spectrogram

# %%
plot_spectrogram(wav_data_synth, rate_synth, 'Synthesized from FAIR Pre-Calc WORLD Features')
plot_spectrogram(wav_data_synth_jiameng, rate_synth_jiameng, 'Synthesized from Jiameng WORLD Features')

# %%
plot_mgc_feature_comparison(feats['audio_features'], feats_jiameng['audio_features'], 'FAIR', 'Jiameng')

# %%
plot_other_feature_comparison(feats['audio_features'], feats_jiameng['audio_features'], 'FAIR', 'Jiameng')

# %% [markdown]
# ## 4) Investigate Pre-Computed .npz Files
# * It's worth knowing what fields are in the .npz files
# * You can see:
#     * Original text
#     * Phonemes generated from the text
#     * Text features
#     * WORLD audio features

# %%
# list of fields
feats.keys()
# Out:
# ['code2phone', 'phonemes', 'language', 'audio_norminfo', 'audio_features']

# %% [markdown]
# #### Original text

# %%
feats['language']
# Out:
# array(1)

# %% [markdown]
# #### Phonemes

# %%
# the phoneme codes for this text transcript
feats['phonemes']
# Out:
# array([27, 11, 31, 12, 30,  1, 20,  9, 22,  4, 37, 12, 23, 13, 31,  1, 24,
#         4, 28, 35, 12, 20,  5, 34, 38, 40, 16])

# %%
# code-to-phone lookup
print feats['code2phone']
print len(feats['code2phone'])
# Out:
# [u'pau' u'iy' u'aa' u'ch' u'ae' u'eh' u'ah' u'ao' u'ih' u'ey' u'aw' u'ay'
#  u'ax' u'er' u'ng' u'sh' u'th' u'uh' u'zh' u'oy' u'dh' u'ow' u'hh' u'jh'
#  u'b' u'd' u'g' u'f' u'k' u'm' u'l' u'n' u'p' u's' u'r' u't' u'w' u'v' u'y'
#  u'z' u'uw']
# 41

# %%
# looked-up phonemes for this text transcript
# i.e. the phonetic version of the original text above
x = feats['phonemes']
#x[x==42] = 0 # for some reason, sometimes there is a phoneme with index=42, which doesn't appear in the dict.
" ".join(feats['code2phone'][x])
# Out:
# u'f ay n ax l iy dh ey hh ae v ax jh er n iy b ae k t ax dh eh r y uw th'

# %% [markdown]
# #### Feature Normalisation Info
# mean and std for each of the 63 features prior to normalisation

# %%
feats['audio_norminfo'].shape
# Out:
# (2, 63)

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.barh(np.linspace(0,63,63), feats['audio_norminfo'][0,:])
plt.grid(True)
plt.title('Mean')

plt.subplot(1,2,2)
plt.barh(np.linspace(0,63,63), feats['audio_norminfo'][1,:])
plt.grid(True)
plt.title('Std')

plt.suptitle('Feature Normalisation Params')
plt.show()

# %% [markdown]
# Note how different the normalisation scales are
# The higher-order mcd are being normalised by very small variances, which blows up the normalised values. Presumably the network then can't really do much to train it away. How much does this matter? Is it effectively a fixed cost? Or is it negatively affecting the training of the network?
#
# Could we floor the standard deviation?

# %% [markdown]
# TODO
#
# * Run all the loss stuff on less-trained models. Do the losses start out similar? And then fall?
#
# * Run glob on the npz files and look for anything in the VCTK set that hasn't been built
#
# * Also compare to the pre-built VoiceLoop dataset - any differences?
#
# * Compare some individual files to the pre-built VoiceLoop dataset? Look/sound similar?
#
# * Quick run of npzloader on the new folders. Could modify to allow specification of which speakers to include?
#
# * Could do quick and dirty copy of files for American speakers to a new folder
#
# * Or could do a neat interface that creates a hashed list thing of train/test split cf. the Tensorflow tutorial? Do with a seed value etc. Base it on config files?
#
# * get_config in python?

# %%
speaker_id = 294
sample_id = 5
pre_calc_features_folder_orig = '/home/ubuntu/loop/data/vctk/numpy_features/'
pre_calc_features_file_orig = os.path.join(pre_calc_features_folder_orig, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
feats_orig = np.load(pre_calc_features_file_orig)

pre_calc_features_folder_new = '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/numpy_features/'
pre_calc_features_file_new = os.path.join(pre_calc_features_folder_new, 
                                      'p' + str(speaker_id) + '_' + '{num:03d}'.format(num=sample_id) + '.npz')
    
feats_new = np.load(pre_calc_features_file_new)

# %%
print type(feats_orig['audio_norminfo'])
print type(feats_new['audio_norminfo'])
# Out:
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>

# %%
feats_new.keys()
# Out:
# ['phonemes', 'code2phone', 'language', 'audio_features', 'audio_norminfo']

# %%
print feats_orig['audio_norminfo'].dtype
print feats_new['audio_norminfo'].dtype
# Out:
# float32
# float32

# %%
type(feats_orig['audio_features'][0][0])
# Out:
# numpy.float32

# %%
type(feats['audio_features'][0][0])
# Out:
# numpy.float64

# %%
x = feats['audio_features']

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x = x.astype(np.float32)

# %%
type(x[0][0])
# Out:
# numpy.float32

# %% [markdown]
# #### WORLD Acoustic Features

# %%
# (# time steps, 63 features)
feats['audio_features'].shape
# Out:
# (433, 63)

# %%
# Is this correct?
plt.plot(feats['audio_features'][:, 61])
plt.grid('True')

# %%
# plot mgc features
plt.figure(figsize=(20,20))
for x in range(60):
    plt.subplot(10, 6, x+1)
    plt.plot(feats['audio_features'][:, x])
    plt.title('mgc' + str(x))

plt.suptitle('mgc features')
plt.show()

# %%
# plot lf0, vuv and bap features
plt.figure(figsize=(20, 4))

plt.subplot(1, 3, 1)
plt.plot(feats['audio_features'][:, 60])
plt.title('vuv')
plt.grid(True)

plt.subplot(1, 3, 2)
plt.plot(feats['audio_features'][:, 61])
plt.title('lf0')
plt.grid(True)

plt.subplot(1, 3, 3)
plt.plot(feats['audio_features'][:, 62])
plt.title('bap')
plt.grid(True)

# %% [markdown]
# ## 5) Check out the samples in the VCTK build
# * Run glob on the folder to see what files are there
# * Compare

# %%
# list of speakers with wav files in the VCTK dataset
speaker_folders = [int(g[len(os.path.join(vctk_raw_folder, 'wav48/p')):-1]) for g in gl.glob(os.path.join(vctk_raw_folder, 'wav48/*', ''))]

print len(speaker_folders)
# Out:
# 109

# %%
# which speaker is missing from the .wav files?
idx_missing = set(speaker_folders) - set(speaker_info['id'])
print idx_missing
# Out:
# set([280])

# %%
# which speaker-samples are in the pre-calculated feature dataset that VoiceLoop uses?
pre_calc_features_folder = vctk_prebuilt_folder + '/numpy_features/'
feat_files = [os.path.basename(g)[:-4] for g in gl.glob(os.path.join(pre_calc_features_folder, '*.npz'))]

print len(feat_files)
# Out:
# 44039

# %%
# find unique speakers in the pre-calculated dataset
feat_split = [f.split('_') for f in feat_files]
loop_speaker_ids = np.unique([int(f[0][1:]) for f in feat_split])
print len(loop_speaker_ids)
#speaker_info[speaker_info.index.isin(loop_speaker_ids)]
# Out:
# 108

# %%
# which American speaker is missing?
idx_missing_american = set(speaker_info[speaker_info.accents == 'American']['id']) - set(loop_speaker_ids)

speaker_info[speaker_info.index.isin(idx_missing_american)]

# (it turns out they have no text transcripts)
# Out:
#       id  age gender   accents       region
# 315  315   18      M  American  New England

# %%
for spkr in loop_speaker_ids:
    feat_split

# %%
pre_built_files = pd.DataFrame(feat_split, columns=('spkr', 'utterance'))

# %%
#pre_built_files.groupby('spkr').count()

# %%
# which speaker-samples are in the pre-calculated feature dataset that VoiceLoop uses?
vctk_prebuilt_folder_orig = '/home/ubuntu/loop/data/vctk'
pre_calc_features_folder_orig = vctk_prebuilt_folder_orig + '/numpy_features/'
feat_files = [os.path.basename(g)[:-4] for g in gl.glob(os.path.join(pre_calc_features_folder_orig, '*.npz'))]

print len(feat_files)
# Out:
# 8015

# %%
for g in gl.glob(os.path.join(pre_calc_features_folder_orig, '*.npz')):
    if not os.path.isfile(os.path.join(vctk_prebuilt_folder, 'numpy_features', os.path.basename(g))):
        print "can't find: " + os.path.basename(g) + ' in ' + vctk_prebuilt_folder
# Out:
# can't find: p345_388.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p306_152.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p361_230.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p306_235.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p306_151.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p306_114.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p341_101.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p300_387.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p345_266.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p329_415.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p306_352.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p306_140.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p330_424.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/
# can't find: p345_292.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/

# %%
for g in gl.glob(os.path.join(pre_calc_features_folder_orig.replace('_features', '_features_valid'), '*.npz')):
    if not os.path.isfile(os.path.join(vctk_prebuilt_folder, 'numpy_features', os.path.basename(g))):
        print "can't find: " + os.path.basename(g) + ' in ' + vctk_prebuilt_folder
# Out:
# can't find: p300_341.npz in /home/ubuntu/vctk-16khz-cmu-no-boundaries/

# %% [markdown]
# So almost all the training files in the VoiceLoop pre-built train and valid folders are present in Jiameng's folder.
# Not sure why there's a handful missing, but not really a problem

# %%
for g in gl.glob(os.path.join(pre_calc_features_folder, '*.npz')):
    #print int(speaker_info[speaker_info.id == int(os.path.basename(g).split('_')[0][1:])]['accents'])
    try:
        if int(speaker_info[speaker_info.id == int(os.path.basename(g).split('_')[0][1:])]['accents'] == 'American') == 1:
            if not os.path.isfile(os.path.join(pre_calc_features_folder_orig,  os.path.basename(g))) and not os.path.isfile(os.path.join(pre_calc_features_folder_orig.replace('_features', '_features_valid'),  os.path.basename(g))):
                print "can't find: " + os.path.basename(g) + ' in ' + pre_calc_features_folder_orig
    except:
        print 'err: ' + os.path.basename(g)
# Out:
# err: p280_193.npz
# err: p280_079.npz
# err: p280_173.npz
# err: p280_171.npz
# err: p280_169.npz
# err: p280_057.npz
# err: p280_209.npz
# err: p280_069.npz
# err: p280_043.npz
# err: p280_067.npz
# err: p280_278.npz
# err: p280_180.npz
# err: p280_253.npz
# err: p280_199.npz
# err: p280_009.npz
# err: p280_233.npz
# err: p280_148.npz
# err: p280_182.npz
# err: p280_051.npz
# err: p280_195.npz
# err: p280_235.npz
# err: p280_094.npz
# err: p280_396.npz
# err: p280_207.npz
# err: p280_125.npz
# err: p280_096.npz
# err: p280_062.npz
# err: p280_105.npz
# err: p280_276.npz
# err: p280_206.npz
# err: p280_122.npz
# err: p280_236.npz
# err: p280_381.npz
# err: p280_305.npz
# err: p280_114.npz
# err: p280_198.npz
# err: p280_081.npz
# err: p280_158.npz
# err: p280_244.npz
# err: p280_288.npz
# err: p280_113.npz
# err: p280_121.npz
# err: p280_126.npz
# err: p280_200.npz
# err: p280_394.npz
# err: p280_103.npz
# err: p280_350.npz
# err: p280_238.npz
# err: p280_100.npz
# err: p280_261.npz
# err: p280_363.npz
# err: p280_273.npz
# err: p280_059.npz
# err: p280_015.npz
# err: p280_342.npz
# err: p280_131.npz
# err: p280_082.npz
# err: p280_066.npz
# err: p280_395.npz
# err: p280_028.npz
# err: p280_345.npz
# err: p280_254.npz
# err: p280_030.npz
# err: p280_266.npz
# err: p280_053.npz
# err: p280_097.npz
# err: p280_095.npz
# err: p280_007.npz
# err: p280_129.npz
# err: p280_379.npz
# err: p280_161.npz
# err: p280_243.npz
# err: p280_308.npz
# err: p280_010.npz
# err: p280_020.npz
# err: p280_372.npz
# err: p280_287.npz
# err: p280_205.npz
# err: p280_123.npz
# err: p280_106.npz
# err: p280_375.npz
# err: p280_405.npz
# err: p280_008.npz
# err: p280_216.npz
# err: p280_359.npz
# err: p280_338.npz
# err: p280_210.npz
# err: p280_357.npz
# err: p280_265.npz
# err: p280_355.npz
# err: p280_184.npz
# err: p280_109.npz
# err: p280_348.npz
# err: p280_220.npz
# err: p280_398.npz
# err: p280_407.npz
# err: p280_410.npz
# err: p280_354.npz
# err: p280_317.npz
# err: p280_388.npz
# err: p280_074.npz
# err: p280_329.npz
# err: p280_343.npz
# err: p280_323.npz
# err: p280_090.npz
# err: p280_187.npz
# err: p280_386.npz
# err: p280_304.npz
# err: p280_011.npz
# err: p280_248.npz
# err: p280_271.npz
# err: p280_229.npz
# err: p280_073.npz
# err: p280_031.npz
# err: p280_215.npz
# err: p280_297.npz
# err: p280_041.npz
# err: p280_155.npz
# err: p280_361.npz
# err: p280_344.npz
# err: p280_116.npz
# err: p280_153.npz
# err: p280_371.npz
# err: p280_330.npz
# err: p280_146.npz
# err: p280_362.npz
# err: p280_409.npz
# err: p280_060.npz
# err: p280_052.npz
# err: p280_274.npz
# err: p280_108.npz
# err: p280_065.npz
# err: p280_256.npz
# err: p280_279.npz
# err: p280_232.npz
# err: p280_269.npz
# err: p280_289.npz
# err: p280_351.npz
# err: p280_077.npz
# err: p280_185.npz
# err: p280_250.npz
# err: p280_402.npz
# err: p280_056.npz
# err: p280_164.npz
# err: p280_369.npz
# err: p280_373.npz
# err: p280_124.npz
# err: p280_284.npz
# err: p280_262.npz
# err: p280_192.npz
# err: p280_356.npz
# err: p280_157.npz
# err: p280_320.npz
# err: p280_302.npz
# err: p280_117.npz
# err: p280_104.npz
# err: p280_331.npz
# err: p280_003.npz
# err: p280_128.npz
# err: p280_377.npz
# err: p280_291.npz
# err: p280_047.npz
# err: p280_140.npz
# err: p280_325.npz
# err: p280_214.npz
# err: p280_190.npz
# err: p280_393.npz
# err: p280_370.npz
# err: p280_352.npz
# err: p280_295.npz
# err: p280_306.npz
# err: p280_013.npz
# err: p280_326.npz
# err: p280_399.npz
# err: p280_083.npz
# err: p280_231.npz
# err: p280_023.npz
# err: p280_006.npz
# err: p280_089.npz
# err: p280_337.npz
# err: p280_404.npz
# err: p280_365.npz
# err: p280_408.npz
# err: p280_115.npz
# err: p280_186.npz
# err: p280_177.npz
# err: p280_191.npz
# err: p280_163.npz
# err: p280_063.npz
# err: p280_068.npz
# err: p280_390.npz
# err: p280_400.npz
# err: p280_376.npz
# err: p280_112.npz
# err: p280_275.npz
# err: p280_133.npz
# err: p280_217.npz
# err: p280_040.npz
# err: p280_002.npz
# err: p280_120.npz
# err: p280_203.npz
# err: p280_282.npz
# err: p280_026.npz
# err: p280_368.npz
# err: p280_234.npz
# err: p280_202.npz
# err: p280_316.npz
# err: p280_017.npz
# err: p280_341.npz
# err: p280_005.npz
# err: p280_264.npz
# err: p280_221.npz
# err: p280_290.npz
# err: p280_165.npz
# err: p280_340.npz
# err: p280_024.npz
# err: p280_160.npz
# err: p280_039.npz
# err: p280_179.npz
# err: p280_230.npz
# err: p280_127.npz
# err: p280_135.npz
# err: p280_292.npz
# err: p280_298.npz
# err: p280_246.npz
# err: p280_152.npz
# err: p280_335.npz
# err: p280_272.npz
# err: p280_078.npz
# err: p280_175.npz
# err: p280_367.npz
# err: p280_219.npz
# err: p280_021.npz
# err: p280_314.npz
# err: p280_036.npz
# err: p280_391.npz
# err: p280_245.npz
# err: p280_307.npz
# err: p280_299.npz
# err: p280_035.npz
# err: p280_406.npz
# err: p280_263.npz
# err: p280_385.npz
# err: p280_029.npz
# err: p280_268.npz
# err: p280_102.npz
# err: p280_259.npz
# err: p280_075.npz
# err: p280_027.npz
# err: p280_183.npz
# err: p280_401.npz
# err: p280_022.npz
# err: p280_046.npz
# err: p280_091.npz
# err: p280_145.npz
# err: p280_042.npz
# err: p280_156.npz
# err: p280_252.npz
# err: p280_349.npz
# err: p280_283.npz
# err: p280_085.npz
# err: p280_084.npz
# err: p280_142.npz
# err: p280_260.npz
# err: p280_353.npz
# err: p280_038.npz
# err: p280_281.npz
# err: p280_346.npz
# err: p280_093.npz
# err: p280_016.npz
# err: p280_366.npz
# err: p280_136.npz
# err: p280_032.npz
# err: p280_061.npz
# err: p280_159.npz
# err: p280_087.npz
# err: p280_324.npz
# err: p280_045.npz
# err: p280_222.npz
# err: p280_312.npz
# err: p280_247.npz
# err: p280_392.npz
# err: p280_170.npz
# err: p280_212.npz
# err: p280_072.npz
# err: p280_242.npz
# err: p280_360.npz
# err: p280_025.npz
# err: p280_389.npz
# err: p280_251.npz
# err: p280_147.npz
# err: p280_143.npz
# err: p280_218.npz
# err: p280_327.npz
# err: p280_167.npz
# err: p280_138.npz
# err: p280_174.npz
# err: p280_313.npz
# err: p280_293.npz
# err: p280_019.npz
# err: p280_237.npz
# err: p280_240.npz
# err: p280_383.npz
# err: p280_049.npz
# err: p280_154.npz
# err: p280_166.npz
# err: p280_034.npz
# err: p280_080.npz
# err: p280_267.npz
# err: p280_150.npz
# err: p280_328.npz
# err: p280_255.npz
# err: p280_201.npz
# err: p280_224.npz
# err: p280_004.npz
# err: p280_070.npz
# err: p280_277.npz
# err: p280_319.npz
# err: p280_012.npz
# err: p280_213.npz
# err: p280_403.npz
# err: p280_258.npz
# err: p280_149.npz
# err: p280_227.npz
# err: p280_058.npz
# err: p280_382.npz
# err: p280_130.npz
# err: p280_333.npz
# err: p280_168.npz
# err: p280_196.npz
# err: p280_139.npz
# err: p280_099.npz
# err: p280_285.npz
# err: p280_107.npz
# err: p280_172.npz
# err: p280_181.npz
# err: p280_303.npz
# err: p280_178.npz
# err: p280_294.npz
# err: p280_296.npz
# err: p280_137.npz
# err: p280_301.npz
# err: p280_280.npz
# err: p280_188.npz
# err: p280_111.npz
# err: p280_001.npz
# err: p280_132.npz
# err: p280_336.npz
# err: p280_092.npz
# err: p280_033.npz
# err: p280_014.npz
# err: p280_176.npz
# err: p280_374.npz
# err: p280_162.npz
# err: p280_134.npz
# err: p280_378.npz
# err: p280_339.npz
# err: p280_211.npz
# err: p280_270.npz
# err: p280_321.npz
# err: p280_347.npz
# err: p280_334.npz
# err: p280_223.npz
# err: p280_332.npz
# err: p280_387.npz
# err: p280_018.npz
# err: p280_098.npz
# err: p280_358.npz
# err: p280_076.npz
# err: p280_226.npz
# err: p280_151.npz
# err: p280_189.npz
# err: p280_088.npz
# err: p280_194.npz
# err: p280_086.npz
# err: p280_384.npz
# err: p280_397.npz
# err: p280_048.npz
# err: p280_310.npz
# err: p280_101.npz
# err: p280_300.npz
# err: p280_225.npz
# err: p280_050.npz
# err: p280_141.npz
# err: p280_322.npz
# err: p280_064.npz
# err: p280_204.npz
# err: p280_054.npz
# err: p280_315.npz
# err: p280_311.npz
# err: p280_228.npz
# err: p280_249.npz
# err: p280_110.npz
# err: p280_380.npz
# err: p280_364.npz
# err: p280_257.npz
# err: p280_144.npz
# err: p280_119.npz
# err: p280_037.npz
# err: p280_071.npz
# err: p280_208.npz
# err: p280_309.npz
# err: p280_239.npz
# err: p280_241.npz
# err: p280_286.npz
# err: p280_197.npz
# err: p280_044.npz
# err: p280_318.npz
# err: p280_055.npz
# err: p280_118.npz

# %% [markdown]
# so all the files for American speakers in Jiameng's folder are also in the VoiceLoop pre-built folder (either train or valid)

# %%
speaker_info[speaker_info.id == 280] # wav files, but no entry in speaker_info! Can we hack in some meta data?
# Out:
# Empty DataFrame
# Columns: [id, age, gender, accents, region]
# Index: []

# %%
int(os.path.basename(g).split('_')[0][1:])
# Out:
# 311

# %%
int(speaker_info[speaker_info.id == int(os.path.basename(g).split('_')[0][1:])]['accents'] == 'American') == 1
# Out:
# True

# %% [markdown]
# ### Manually create the norm files

# %%
norm_info_file = '/home/ubuntu/loop/data/vctk/norm_info/norm.dat'
#norm_info_file = '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/norm_info/norm.dat'
fid = open(norm_info_file, 'rb')
cmp_info = np.fromfile(fid, dtype=np.float32)
fid.close()

cmp_info = cmp_info.reshape((2, -1))
cmp_mean = cmp_info[0, ]
cmp_std = cmp_info[1, ]

# %%
#np.array([cmp_mean, cmp_std]).transpose()
#cmp_info

# %%
#get_loader(data_path='data/vctk', 
max_seq_len=1000
batch_size=64,
nspk=22
data_path='../data/vctk-16khz-cmu-no-boundaries-us'
#data_path='../data/vctk'
dataset = NpzFolder(data_path + '/numpy_features', nspk == 1)
loader = NpzLoader(dataset,
                         max_seq_len=max_seq_len,
                         batch_size=batch_size,
                         num_workers=4,
                         pin_memory=True)

# %%
tmp_feat = np.load(loader.dataset.npzs[0])
tmp_norm = tmp_feat['audio_norminfo']

# %%
for i in range(1,8000):
    tmp_feat = np.load(loader.dataset.npzs[0])
    test_norm = tmp_feat['audio_norminfo']
    #assert np.array_equal(tmp_norm, test_norm), "problem"
    assert np.array_equal(cmp_info, test_norm), "problem"

# %%
# write out norm info to file
norm_info_file = '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/norm_info/norm.dat'
#tmp_norm.flatten().tofile(file=norm_info_file)

# %%
fid = open(norm_info_file, 'rb')
cmp_info_reload = np.fromfile(fid, dtype=np.float32)
fid.close()

cmp_info_reload = cmp_info_reload.reshape((2, -1))
cmp_mean_reload = cmp_info_reload[0, ]
cmp_std_reload = cmp_info_reload[1, ]

# %%
np.array_equal(cmp_info_reload, tmp_norm)
# Out:
# True

# %%
new = copy.deepcopy(cmp_info_reload)

# %%
old = copy.deepcopy(cmp_info_reload)

# %%
plt.plot(np.vstack([new[0,:], old[0,:]]).transpose())
plt.grid(True)
plt.show()

plt.plot(np.vstack([new[1,:], old[1,:]]).transpose())
plt.grid(True)
plt.show()

# %%
#np.vstack([new[0,:], old[0,:]]).transpose()

# %% [markdown]
# ### Copy the American files across to a new folder

# %%
template_folder = '/home/ubuntu/loop/data/vctk'
folder_list = ('numpy_features', 'numpy_features_valid')
src_folder = '/home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features'
dest_folder = '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us'

for f in folder_list:
    this_template = os.path.join(template_folder, f)
    this_dest = os.path.join(dest_folder, f)
    
    try:
        os.makedirs(this_dest)
    except:
        print "error"
    
    for g in gl.glob(os.path.join(this_template, '*.npz')):
        src_file = os.path.join(src_folder, os.path.basename(g))
        
        try:
            #print src_file
            sh.copy(src_file, this_dest)
        except:
            print "Couldn't copy: " + src_file
# Out:
# error
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p345_388.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_152.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p361_230.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_235.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_151.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_114.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p341_101.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p300_387.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p345_266.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p329_415.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_352.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_140.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p330_424.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p345_292.npz
# error
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p300_341.npz

# %%
os.listdir('/home/ubuntu/loop/data/vctk/norm_info')
# Out:
# ['norm.dat']

# %%
sh.copytree('/home/ubuntu/loop/data/vctk/norm_info', '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/norm_info')

# %%
for f in folder_list:
    this_template = os.path.join(template_folder, f)
    this_dest = os.path.join(dest_folder, f)
    
    try:
        os.makedirs(this_dest)
    except:
        print "error"
    
    for g in gl.glob(os.path.join(this_template, '*.npz')):
        src_file = os.path.join(src_folder, os.path.basename(g))
        dest_file = os.path.join(this_dest, os.path.basename(g))
        
        try:
            tmp = dict(np.load(src_file))
            tmp['audio_features'] = tmp['audio_features'].astype(np.float32)
            tmp['audio_norminfo'] = tmp['audio_norminfo'].astype(np.float32)
            
            save_dict = {
                    'audio_features': tmp['audio_features'],
                    'code2phone': tmp['code2phone'],
                    'phonemes': tmp['phonemes'],
                    'language': tmp['language'],
                    'audio_norminfo': tmp['audio_norminfo'],
                }
            
            np.savez_compressed(dest_file, **tmp)
            #np.savez(dest_file, tmp)
        except:
            print "Couldn't copy: " + src_file
# Out:
# error
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p345_388.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_152.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p361_230.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_235.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_151.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_114.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p341_101.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p300_387.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p345_266.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p329_415.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_352.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p306_140.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p330_424.npz
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p345_292.npz
# error
# Couldn't copy: /home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features/p300_341.npz

# %%
tmp['audio_norminfo'].dtype
# Out:
# dtype('float32')

# %%
x = tmp['audio_features'].astype(np.float32)

# %%
dest_file
# Out:
# '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/numpy_features_valid/p311_349.npz'

# %%
save_dict = {
        'audio_features': tmp['audio_features'],
        'code2phone': tmp['code2phone'],
        'phonemes': tmp['phonemes'],
        'language': tmp['language'],
        'audio_norminfo': tmp['audio_norminfo'],
    }
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-316-cfe5f8e1f8a9> in <module>()
#       1 save_dict = {
# ----> 2         'audio_features': tmp['audio_features'],
#       3         'code2phone': tmp['code2phone'],
#       4         'phonemes': tmp['phonemes'],
#       5         'language': tmp['language'],
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in __getitem__(self, key)
#     235                 return self.zip.read(key)
#     236         else:
# --> 237             raise KeyError("%s is not a file in the archive" % key)
#     238
#     239     def __iter__(self):
#
# KeyError: 'audio_features is not a file in the archive'

# %%
np.savez_compressed(dest_file, **tmp)

# %%
dest_file
# Out:
# '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/numpy_features_valid/p311_349.npz'

# %%
tmp = np.load(dest_file)

# %%
tmp.keys()
# Out:
# ['phonemes', 'code2phone', 'language', 'audio_features', 'audio_norminfo']

# %% [markdown]
# ### Creating a Scottish Dataset!

# %%
scottish_speakers = speaker_info[speaker_info['accents'] == 'Scottish']

# %%
feat_files = [os.path.basename(g)[:-4] for g in gl.glob(os.path.join('/home/ubuntu/loop/data/vctk/numpy_features', '*.npz'))]

# %%
len(np.unique([f.split('_')[0] for f in feat_files]))
# Out:
# 21

# %%
len(feat_files)
# Out:
# 8015

# %%
feat_files = [os.path.basename(g)[:-4] for g in gl.glob(os.path.join('/home/ubuntu/loop/data/vctk/numpy_features_valid', '*.npz'))]

# %%
len(np.unique([f.split('_')[0] for f in feat_files]))
# Out:
# 21

# %%
len(feat_files)
# Out:
# 700

# %% [markdown]
# so the train/validation sets have the same set of speakers (i.e. no speakers are completely held-out)
#
# Validation set is less than 10% of the size of the training set

# %%
feat_files = [os.path.basename(g)[:-4] for g in gl.glob(os.path.join('/home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features', '*.npz'))]

# %%
len(feat_files)
# Out:
# 44039

# %%
all_spkr_id = [int(f.split('_')[0][1:]) for f in feat_files]

# %%
scottish_sprk_id = scottish_speakers['id'].values

# %%
num_scottish = len(scottish_speakers)

# %%
num_samples_for_speaker = np.zeros(num_scottish)
num_samples_for_speaker_valid = np.zeros(num_scottish, dtype=np.int8)
train_samples_for_speaker = []
valid_samples_for_speaker = []

for i, spkr in enumerate(scottish_sprk_id):
    idx_this_spkr = np.array([j == spkr for j in all_spkr_id])
    num_samples_for_speaker[i] = np.sum(idx_this_spkr)
    
    num_samples_for_speaker_valid[i] = np.int(np.floor(num_samples_for_speaker[i] * 0.1))
    
    flat_idx = np.flatnonzero(idx_this_spkr)
    np.random.shuffle(flat_idx)
    
    valid_samples_for_speaker.append(flat_idx[:num_samples_for_speaker_valid[i]])
    train_samples_for_speaker.append(flat_idx[num_samples_for_speaker_valid[i]:])

# %%
src_folder = '/home/ubuntu/vctk-16khz-cmu-no-boundaries/numpy_features'
dest_folder = '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-sc'
feat_files_array = np.array(feat_files)

for i, spkr in enumerate(scottish_sprk_id):
    #f = 'numpy_features'
    f = 'numpy_features_valid'
    this_dest = os.path.join(dest_folder, f)
    
    try:
        os.makedirs(this_dest)
    except:
        pass
    
    #for t in feat_files_array[train_samples_for_speaker[i]]:
    for t in feat_files_array[valid_samples_for_speaker[i]]:
        this_src = os.path.join(src_folder, t+'.npz')
        this_dest_file = os.path.join(this_dest, t+'.npz')
        #print this_src, this_dest
        # also need to convert the floats... then copy
        
        try:
            tmp = dict(np.load(this_src))
            tmp['audio_features'] = tmp['audio_features'].astype(np.float32)
            tmp['audio_norminfo'] = tmp['audio_norminfo'].astype(np.float32)
            
            save_dict = {
                    'audio_features': tmp['audio_features'],
                    'code2phone': tmp['code2phone'],
                    'phonemes': tmp['phonemes'],
                    'language': tmp['language'],
                    'audio_norminfo': tmp['audio_norminfo'],
                }
            
            np.savez_compressed(this_dest_file, **tmp)
            #np.savez(dest_file, tmp)
        except:
            print "Couldn't copy: " + src_file

# %%
print len(os.listdir(os.path.join(dest_folder, 'numpy_features')))
print len(os.listdir(os.path.join(dest_folder, 'numpy_features_valid')))
# Out:
# 6856
# 751

# %%
print 6856 + 751
# Out:
# 7607

# %%
len(feat_files)
# Out:
# 44039

# %%
np.sum([np.sum(scottish_sprk_id == s) for s in all_spkr_id])
# Out:
# 7607

# %% [markdown]
# #### Copy norm_info file

# %%
sh.copytree('/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-us/norm_info', '/home/ubuntu/loop/data/vctk-16khz-cmu-no-boundaries-sc/norm_info')

# %% [markdown]
# ## 6) Using PyDub to view frame rate etc.
# Not especially useful

# %%
song = pyd.AudioSegment.from_wav(wav_file)

# %%
print "frame rate: " + str(song.frame_rate)
print "sample width: " + str(song.sample_width)
print "channels: " + str(song.channels)
print "duration (sec): " + str(song.duration_seconds)
# Out:
# frame rate: 48000
# sample width: 2
# channels: 1
# duration (sec): 6.2728125

# %% [markdown]
# ## TODO
# * Phonemizer
